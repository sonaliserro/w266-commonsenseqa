# %%
import torch
import nlp

from transformers import T5ForConditionalGeneration, T5Tokenizer

from tqdm.auto import tqdm

from sklearn import metrics

# %%
device = 'cuda' if torch.cuda.is_available else 'cpu'

# %% [markdown]
# #### Evaluate the model fine-tuned on commonsense_qa for 3 epochs

# %%
# Load the pretrained model
commonsense_qa_model = T5ForConditionalGeneration.from_pretrained('./models/commonsense_qa/10_epochs')
commonsense_qa_tokenizer = T5Tokenizer.from_pretrained('./models/commonsense_qa/10_epochs')

# %%
# Load the validation dataset
commonsense_qa_valid_dataset = torch.load('./data/commonsense_qa/valid_data.pt')
commonsense_qa_dataloader = torch.utils.data.DataLoader(commonsense_qa_valid_dataset, batch_size = 32)

# %%
# Generate predictions
commonsense_qa_predictions = []
commonsense_qa_targets = []
commonsense_qa_model.to(device)    
commonsense_qa_model.eval()
with torch.no_grad():
    for batch in tqdm(commonsense_qa_dataloader):
        prediction = commonsense_qa_model.generate(input_ids = batch['input_ids'].to(device), 
                          attention_mask = batch['attention_mask'].to(device),
                          max_length = 16)
        prediction = [commonsense_qa_tokenizer.decode(ids) for ids in prediction]
        target = [commonsense_qa_tokenizer.decode(ids) for ids in batch['target_ids']]
    
        commonsense_qa_predictions.extend(prediction)
        commonsense_qa_targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=39.0), HTML(value='')))

# %%
metrics.accuracy_score(commonsense_qa_targets, commonsense_qa_predictions)
# Out:
# 0.6404586404586404

# %%
incorrect_idxs = [i for i, prediction in enumerate(commonsense_qa_predictions) if prediction != commonsense_qa_targets[i]]
for incorrect_idx in incorrect_idxs:
    print(commonsense_qa_tokenizer.decode(commonsense_qa_valid_dataset[incorrect_idx]['input_ids']))
    print("Target Answer: {}".format(commonsense_qa_tokenizer.decode(commonsense_qa_valid_dataset[incorrect_idx]['target_ids'])))
    print("Predicted Answer: {}".format(commonsense_qa_predictions[incorrect_idx]))
# Out:
# question: A revolving door is convenient for two direction travel, but it also serves as a security measure at a what? options: A: bank B: library C: department store D: mall E: new york
# Target Answer: A: bank
# Predicted Answer: D: mall
# question: Where would you find magazines along side many other printed works? options: A: doctor B: bookstore C: market D: train station E: mortuary
# Target Answer: B: bookstore
# Predicted Answer: C: market
# question: James was looking for a good place to buy farmland. Where might he look? options: A: midwest B: countryside C: estate D: farming areas E: illinois
# Target Answer: A: midwest
# Predicted Answer: C: estate
# question: What island country is ferret popular? options: A: own home B: north carolina C: great britain D: hutch E: outdoors
# Target Answer: C: great britain
# Predicted Answer: B: north carolina
# question: What would vinyl be an odd thing to replace? options: A: pants B: record albums C: record store D: cheese E: wallpaper
# Target Answer: E: wallpaper
# Predicted Answer: B: record albums
# question: When drinking booze what can you do to stay busy? options: A: reach tentative agreement B: stay in bed C: stop bicycle D: examine thing E: suicide
# Target Answer: D: examine thing
# Predicted Answer: B: stay in bed
# question: A fencing thrust with a sharp sword towards a person would result in what? options: A: injury B: small cuts C: fever D: competition E: puncture wound
# Target Answer: E: puncture wound
# Predicted Answer: A: injury
# question: Where do adults use glue sticks? options: A: classroom B: desk drawer C: at school D: office E: kitchen drawer
# Target Answer: D: office
# Predicted Answer: A: classroom
# question: Though the thin film seemed fragile, for it's intended purpose it was actually nearly what? options: A: indestructible B: durable C: undestroyable D: indestructible E: unbreakable
# Target Answer: D: indestructible
# Predicted Answer: B: durable
# question: Where could you find a toilet that only friends can use? options: A: rest area B: school C: stadium D: apartment E: hospital
# Target Answer: D: apartment
# Predicted Answer: A: rest area
# question: What is someone who isn't clever, bright, or competent called? options: A: clumsy B: ineffectual C: dull D: clumsy E: stupid
# Target Answer: E: stupid
# Predicted Answer: A: clumsy
# question: Blue read material outside of his comfort zone because he wanted to gain what? options: A: new perspective B: entertained C: understanding D: hunger E: tired eyes
# Target Answer: A: new perspective
# Predicted Answer: C: understanding
# question: She was always helping at the senior center, it brought her what? options: A: satisfaction B: heart C: feel better D: pay E: happiness
# Target Answer: E: happiness
# Predicted Answer: A: satisfaction
# question: If you have leftover cake, where would you put it? options: A: quandry B: refrigerator C: oven D: night stand E: bakery
# Target Answer: B: refrigerator
# Predicted Answer: C: oven
# question: Where can you put a picture frame when it's not hung vertically? options: A: art show B: wall C: newspaper D: car E: table
# Target Answer: E: table
# Predicted Answer: B: wall
# question: What must someone do before they shop? options: A: get money B: have money C: bring cash D: go to market E: bring cash
# Target Answer: A: get money
# Predicted Answer: E: bring cash
# question: Because John was first violin, he had to bring something important to work ever day. What did he need to bring to work? options: A: music store B: obesity C: symphony orchestra D: ochestra E: violin case
# Target Answer: E: violin case
# Predicted Answer: C: symphony orchestra
# question: Who is likely to be excited about a crab? options: A: fish market B: pet shop C: fishmongers D: intertidal zone E: obesity
# Target Answer: C: fishmongers
# Predicted Answer: B: pet shop
# question: The freeway had no traffic and few buildings, where is it? options: A: california B: countryside C: big town D: florida E: america
# Target Answer: B: countryside
# Predicted Answer: D: florida
# question: Where would you go if you wanted to have fun with a few people? options: A: watching television B: good C: cinema D: friend's house E: fairgrounds
# Target Answer: D: friend's house
# Predicted Answer: E: fairgrounds
# question: If there is a place that is hot and arid, what could it be? options: A: bland B: lifeless C: sandy D: neutral E: freezing
# Target Answer: B: lifeless
# Predicted Answer: C: sandy
# question: What is likely to satisfy someone's curiosity? options: A: hear news B: read book C: see favorite show D: comedy show E: go somewhere
# Target Answer: A: hear news
# Predicted Answer: B: read book
# question: Where can you find a snake in tall grass? options: A: tree B: in a jar C: pet shops D: feild E: tropical forest
# Target Answer: D: feild
# Predicted Answer: A: tree
# question: Where is a human likely to go as a result of being hungry? options: A: eat in restaurant B: make bread C: have lunch D: cook dinner E: friends house
# Target Answer: A: eat in restaurant
# Predicted Answer: C: have lunch
# question: Where would you find a single shower curtain being used? options: A: bathtub B: washing area C: hotel D: shower stall E: department store
# Target Answer: A: bathtub
# Predicted Answer: C: hotel
# question: What would not be true about a basketball if it had a hole in it but it did not lose its general shape? options: A: punctured B: popular in america C: full of air D: gone E: round
# Target Answer: C: full of air
# Predicted Answer: E: round
# question: Where would you expect to find white mice? options: A: bell cat B: bush C: attic D: countryside E: laboratory
# Target Answer: E: laboratory
# Predicted Answer: B: bush
# question: What could committing murder prevent someone from doing? options: A: go to jail B: cry C: find god D: guilty conscience E: problems
# Target Answer: C: find god
# Predicted Answer: E: problems
# question: The man had a fear of illness, so he never visited friends who were a what? options: A: sick person B: hospital C: elderly person D: graveyard E: doctor's office
# Target Answer: A: sick person
# Predicted Answer: C: elderly person
# question: Where can you find a number of wind instruments together in public? options: A: music store B: create music C: zoo D: music room E: symphony
# Target Answer: E: symphony
# Predicted Answer: D: music room
# question: A mountie got off at a subway stop. What city might he be in? options: A: urban area B: metropolis C: chicago D: new york city E: toronto
# Target Answer: E: toronto
# Predicted Answer: D: new york city
# question: What do you want someone to do when you illustrate point? options: A: did not understand B: accepting C: make clear D: understood E: understanding
# Target Answer: E: understanding
# Predicted Answer: C: make clear
# question: Billy set aside a block of time for having fun after work. Why might he do this? options: A: happiness B: stress relief C: pleasure D: ocean E: may laugh
# Target Answer: B: stress relief
# Predicted Answer: C: pleasure
# question: What would you be unable to do if you have too much greed? options: A: keep things B: make friends C: play poker D: conquer opponent E: lie
# Target Answer: B: make friends
# Predicted Answer: D: conquer opponent
# question: It was a long trip from the farm, so he stayed in a hotel when he arrived at the what? options: A: bed away from home B: wwii bunker C: resort D: las vegas E: city
# Target Answer: E: city
# Predicted Answer: D: las vegas
# question: What would encourage someone to continue playing tennis? options: A: becoming tired B: tennis elbow C: exercise D: hunger E: victory
# Target Answer: E: victory
# Predicted Answer: C: exercise
# question: Where could a person avoid the rain? options: A: bus stop B: tunnel C: synagogue D: fairy tale E: street corner
# Target Answer: C: synagogue
# Predicted Answer: A: bus stop
# question: John and James are idiots. They bought two tickets to the Falcons vs the Jets even though neither wanted to see the what? options: A: internet cafe B: sporting event C: pressing wrong buttons D: obesity E: hockey game
# Target Answer: B: sporting event
# Predicted Answer: E: hockey game
# question: The tourist entered Mammoth cave, what state were they in? options: A: west virginia B: kentucky C: rocky hills D: scotland E: canyon
# Target Answer: B: kentucky
# Predicted Answer: A: west virginia
# question: Sam was a stranger. Even so, Mark treated him like what? options: A: friend B: family C: known person D: park E: outsider
# Target Answer: B: family
# Predicted Answer: A: friend
# question: Bob's only light source was a small bulb. There were four walls, if there was a door he couldn't see it. What was Bob in? options: A: closed room B: sky C: dard D: his grave E: house
# Target Answer: A: closed room
# Predicted Answer: E: house
# question: With the card slot lit up he knew how to get started finding his balance with what? options: A: slot machine B: ticket machine C: bank machine D: telephone E: automated teller
# Target Answer: E: automated teller
# Predicted Answer: C: bank machine
# question: The child pretended he was reading newspaper, he couldn't actually do it without what? options: A: patience B: falling down C: literacy D: buying E: knowing how to read
# Target Answer: E: knowing how to read
# Predicted Answer: A: patience
# question: Jenny enjoyed helping people. It brought her a great deal of what? options: A: satisfaction B: complications C: train D: feel good about yourself E: enjoyment
# Target Answer: A: satisfaction
# Predicted Answer: E: enjoyment
# question: What might someone believe in if they are cleaning clothes? options: A: feminism B: sanitation C: ruined D: wrinkles E: buttons to fall off
# Target Answer: B: sanitation
# Predicted Answer: A: feminism
# question: Where would you find a basement that can be accessed with an elevator? options: A: eat cake B: closet C: church D: office building E: own house
# Target Answer: D: office building
# Predicted Answer: E: own house
# question: What part of plants is pretty? options: A: dirt B: no neurons in C: millions of cells D: flowers on E: roots
# Target Answer: D: flowers on
# Predicted Answer: E: roots
# question: What could you get an unsmooth pit from? options: A: backyard B: rock C: mine D: cherry E: peach
# Target Answer: E: peach
# Predicted Answer: B: rock
# question: The man tried to reply to the woman, but he had difficulty keeping track of conversations that he didn't do what to? options: A: initiate B: ignore C: question D: answer E: ask
# Target Answer: A: initiate
# Predicted Answer: B: ignore
# question: How can someone be let into a brownstone? options: A: brooklyn B: ring C: subdivision D: bricks E: new york city
# Target Answer: B: ring
# Predicted Answer: C: subdivision
# question: Where are people likely to become impatient? options: A: end of line B: buildings C: apartment D: neighbor's house E: address
# Target Answer: A: end of line
# Predicted Answer: B: buildings
# question: When you fail to finish something, you failed at doing what to it options: A: winning B: passing C: completing D: do well E: succeeding
# Target Answer: C: completing
# Predicted Answer: E: succeeding
# question: John didn't care about style. He felt that form was less important than what? options: A: shapeless B: quality C: function D: change shape E: chaos
# Target Answer: C: function
# Predicted Answer: B: quality
# question: When you get together with friends to watch film, you might do plenty of this? options: A: see what happens B: enjoy stories C: pass time D: have fun E: interesting
# Target Answer: D: have fun
# Predicted Answer: B: enjoy stories
# question: Bill puts meat on the scale, where does Bill work? options: A: music store B: assay office C: tidal wave D: butcher shop E: bathroom
# Target Answer: D: butcher shop
# Predicted Answer: B: assay office
# question: I'm having some food at my party, what will I need to serve it? options: A: zoo B: pan C: bowl D: kitchen E: spoon
# Target Answer: E: spoon
# Predicted Answer: C: bowl
# question: Why would you be watching tv instead of doing something else? options: A: headache B: laughter C: laziness D: erections E: wasting time
# Target Answer: C: laziness
# Predicted Answer: E: wasting time
# question: He had to wear a tuxedo while playing the keyboard instrument, so did the other hundred members of the what? options: A: music store B: band C: medium D: orchestra E: piano store
# Target Answer: D: orchestra
# Predicted Answer: B: band
# question: Where do you find the most amount of leafs? options: A: floral arrangement B: ground C: forrest D: field E: compost pile
# Target Answer: C: forrest
# Predicted Answer: B: ground
# question: Where would you find a monkey in the wild? options: A: zoo B: barrel C: research laboratory D: captivity E: thailand
# Target Answer: E: thailand
# Predicted Answer: D: captivity
# question: If you take the risk buying a used car, you still hope it can what? options: A: go fast B: start running C: going too fast D: look good E: last several years
# Target Answer: E: last several years
# Predicted Answer: D: look good
# question: What do airplanes do as they are arriving at the gate? options: A: slow down B: crash C: speed up D: land E: carry people
# Target Answer: A: slow down
# Predicted Answer: C: speed up
# question: The gimmicky low brow TV show was about animals when they what? options: A: sick B: mammals C: males D: bite E: attack
# Target Answer: E: attack
# Predicted Answer: B: mammals
# question: A loud machine is irritating, but many are expected where? options: A: museum B: house C: laboratory D: library E: industrial area
# Target Answer: E: industrial area
# Predicted Answer: C: laboratory
# question: What part of a table would you put a ruler in? options: A: drawer B: desk C: the backside D: office E: measure distance
# Target Answer: A: drawer
# Predicted Answer: B: desk
# question: Where would stones not be arranged in a path? options: A: quarries B: field C: park D: bridge E: made from rocks
# Target Answer: B: field
# Predicted Answer: D: bridge
# question: What is likely to happen to someone who is learning? options: A: overconfidence B: effectiveness C: knowing more D: head grows larger E: growth
# Target Answer: C: knowing more
# Predicted Answer: E: growth
# question: Where do you go on a night out before going to the bar? options: A: new york city B: las vegas C: restaurant D: nightclub E: park
# Target Answer: C: restaurant
# Predicted Answer: D: nightclub
# question: The dad wanted to protect his house, where did he put his gun? options: A: police station B: crime scene C: restroom D: drawer E: holster
# Target Answer: D: drawer
# Predicted Answer: E: holster
# question: What animal has quills all over it? options: A: feather B: chicken C: calligraphy D: porcupine E: hedgehog
# Target Answer: E: hedgehog
# Predicted Answer: D: porcupine
# question: What is performing a type of? options: A: singing B: act C: feat D: smile E: acting
# Target Answer: B: act
# Predicted Answer: E: acting
# question: What might a very large table be? options: A: dining room B: conference C: kitchen D: in a lake E: demonstration
# Target Answer: B: conference
# Predicted Answer: A: dining room
# question: Where is a ferret unlikely to be? options: A: classroom B: outdoors C: aquarium D: north carolina E: great britain
# Target Answer: A: classroom
# Predicted Answer: B: outdoors
# question: If you jump in any of the oceans you will get? options: A: tanned B: wet C: wide D: very deep E: fish
# Target Answer: B: wet
# Predicted Answer: D: very deep
# question: Immediately after peeing, a person's bladder is what? options: A: collapsed B: empty C: full D: filled E: stretchable
# Target Answer: B: empty
# Predicted Answer: C: full
# question: The lady would eat and eat, and because of mental issues would then make herself what? options: A: wash dishes B: throwing up C: drinking D: throw up E: turn inside out
# Target Answer: D: throw up
# Predicted Answer: C: drinking
# question: A car was hailed to chauffeur someone to the opera house, where was it heading? options: A: go downtown B: appear suddenly C: go fast D: bottom out E: east
# Target Answer: A: go downtown
# Predicted Answer: E: east
# question: The teacher thought that a ferret can be very mischievous and probably wouldn't make a great pet for the entire what? options: A: bad mood B: hutch C: classroom D: pair of trousers E: year
# Target Answer: C: classroom
# Predicted Answer: E: year
# question: What is a treat that you dog will enjoy? options: A: salad B: petted C: affection D: bone E: lots of attention
# Target Answer: D: bone
# Predicted Answer: A: salad
# question: Women used to be expected to wear a dress but it's now acceptable for them to wear what? options: A: man suit B: pants C: naked D: action E: long skirt
# Target Answer: B: pants
# Predicted Answer: E: long skirt
# question: The fact that Joe was able to memorize the list in spite of his apparent state proved that part of his brain was what? options: A: awake B: repeat C: sleeping D: concentrate E: read aloud
# Target Answer: A: awake
# Predicted Answer: D: concentrate
# question: What is a wet person likely to do? options: A: gain weight B: thank god C: catch cold D: suicide E: cross street
# Target Answer: C: catch cold
# Predicted Answer: A: gain weight
# question: The painter started to edge the room with tape, he always took extra care to make the lines clean and crisp when working with an what? options: A: triangle B: middle C: corner D: center E: interior
# Target Answer: E: interior
# Predicted Answer: A: triangle
# question: Minerals can be obtained in what way for a person who avoids leafy greens? options: A: multivitamin B: farm C: michigan D: earth E: ore
# Target Answer: A: multivitamin
# Predicted Answer: E: ore
# question: What could you be a few hours after you finish cashing in due to your cash? options: A: happy B: receiving money C: getting paid D: spending money E: selling out
# Target Answer: A: happy
# Predicted Answer: B: receiving money
# question: What might a couple have a lot of when they are deciding on stopping being married to each other? options: A: pleasure B: detachment C: exercise D: bankruptcy E: fights
# Target Answer: E: fights
# Predicted Answer: B: detachment
# question: Billy hated using other people's toilets. He was only comfortable on his own. So whenever he needed to poop, he would go back to his what? options: A: bathroom B: motel room C: nearest public restroom D: house E: apartment
# Target Answer: D: house
# Predicted Answer: C: nearest public restroom
# question: The forest experienced a cold winter, where is it located? options: A: earth B: south america C: amazon basin D: temperate zone E: national park
# Target Answer: D: temperate zone
# Predicted Answer: C: amazon basin
# question: Where is one likely to find a brownstone? options: A: new york city B: subdivision C: ring D: hazleton E: live in
# Target Answer: A: new york city
# Predicted Answer: B: subdivision
# question: John went to a party that lasted all night. Because of this, he didn't have time for what? options: A: meeting B: blowing off steam C: stay home D: partying hard E: studying
# Target Answer: E: studying
# Predicted Answer: C: stay home
# question: When someone is physically competing what does their body do? options: A: tension B: perform better C: releases heat D: winning or losing E: sweat
# Target Answer: E: sweat
# Predicted Answer: C: releases heat
# question: How would you express information to a deaf person? options: A: summarize main points B: close mouth C: write down D: may disagree E: talk
# Target Answer: C: write down
# Predicted Answer: E: talk
# question: What will god never do according to religion? options: A: anything B: judge people C: work miracles D: judge men E: everywhere
# Target Answer: B: judge people
# Predicted Answer: A: anything
# question: One of the potential hazards of attending school is what? options: A: cooties B: get smart C: boredom D: colds and flu E: taking tests
# Target Answer: D: colds and flu
# Predicted Answer: C: boredom
# question: What has a surface with many sides? options: A: tetrahedron B: object C: geometry problem D: lake E: triangle
# Target Answer: A: tetrahedron
# Predicted Answer: E: triangle
# question: The old style pop ups literally let you see the story when you did what? options: A: giggle B: visualize C: open book D: reading E: go to movies
# Target Answer: C: open book
# Predicted Answer: D: reading
# question: The family finished dinner, the child's chore was to load the dirty dishes where? options: A: restaurant kitchen B: dishwasher C: son's room D: cabinet E: party
# Target Answer: B: dishwasher
# Predicted Answer: C: son's room
# question: Where could you find a bureau as well as many politicians? options: A: each city B: office building C: a zoo D: french government E: washington dc
# Target Answer: E: washington dc
# Predicted Answer: A: each city
# question: Where are horses judged on appearance? options: A: race track B: fair C: raised by humans D: in a field E: countryside
# Target Answer: B: fair
# Predicted Answer: A: race track
# question: Why do people read non fiction? options: A: having fun B: it's more relatable C: learn new things D: becoming absorbed E: falling asleep
# Target Answer: C: learn new things
# Predicted Answer: B: it's more relatable
# question: John had a massive debt to 50 million dollars. Compared to that, Leo's 2000 dollar debt seemed what? options: A: dwarf B: inconsequential C: insubstantial D: lame E: tiny
# Target Answer: C: insubstantial
# Predicted Answer: A: dwarf
# question: The man flew his airplane over the city and saw pollution visibly in the sky, what was polluted? options: A: forest B: street C: air D: caused by humans E: car show
# Target Answer: C: air
# Predicted Answer: B: street
# question: If not in a stream but in a market where will you find fish? options: A: stream B: aquarium C: refrigerator D: boat ride E: market
# Target Answer: C: refrigerator
# Predicted Answer: E: market
# question: Where would you put a glass after drinking from it? options: A: ocean B: water cooler C: cabinet D: dishwasher E: dining room
# Target Answer: D: dishwasher
# Predicted Answer: C: cabinet
# question: Kramer wrote a self-referential book. What might that book be about? options: A: counter B: coffee table C: school room D: backpack E: bedside table
# Target Answer: B: coffee table
# Predicted Answer: C: school room
# question: Of all the sports, Billy enjoys football, but what does his concerned mother think of the sport? options: A: very entertaining B: fun C: slow D: competitive E: violent
# Target Answer: E: violent
# Predicted Answer: D: competitive
# question: What city will likely have many parking structures? options: A: chicago B: big city C: large city building D: environment E: college campus
# Target Answer: A: chicago
# Predicted Answer: B: big city
# question: What is the habitat of the fox? options: A: hen house B: burrow C: california D: england E: mountains
# Target Answer: E: mountains
# Predicted Answer: D: england
# question: People are very much like the animals, but one thing has secured or dominance over the planet. We're better at doing what? options: A: eat eggs B: make tools C: eat dosa D: talk to each other E: smoke pot
# Target Answer: B: make tools
# Predicted Answer: D: talk to each other
# question: They children loved having a back yard, and the parents loved that it was a safe what? options: A: suburb B: neighborhood C: back of house D: roundabout E: property
# Target Answer: B: neighborhood
# Predicted Answer: E: property
# question: They passed a apple tree on their way to the racetrack, the were going to watch the biggest motorsport spectacle in the world where? options: A: maryland B: indiana C: on tv D: park E: new jersey
# Target Answer: B: indiana
# Predicted Answer: A: maryland
# question: What do you need energy to do in gym class? options: A: work B: tacos C: mass D: play sports E: wrestle
# Target Answer: D: play sports
# Predicted Answer: A: work
# question: We are all human, and we all what? options: A: write B: eat cake C: smile D: think critically E: die
# Target Answer: E: die
# Predicted Answer: human
# question: What happens at soon as a living being is born? options: A: expiration B: growing older C: sometimes bad D: death E: start reproduction
# Target Answer: B: growing older
# Predicted Answer: A: expiration
# question: The cancer patient was expecting to die, so he made out his what? options: A: not to live B: write will C: never want D: seek help E: go to hell
# Target Answer: B: write will
# Predicted Answer: A: not to live
# question: There was a toll road that meandered from Maine to New Hampshire, where was it? options: A: massachusetts B: new england C: my house D: new jersey E: connecticut
# Target Answer: B: new england
# Predicted Answer: A: massachusetts
# question: The cat carefully navigated the area, they do everything they can to avoid what? options: A: get wet B: eat vegetables C: falling D: wool sweater E: sharp claws
# Target Answer: A: get wet
# Predicted Answer: C: falling
# question: What does the sky do before a rain? options: A: appear beautiful B: appear blue C: shows a rainbow D: rain water E: cloud over
# Target Answer: E: cloud over
# Predicted Answer: B: appear blue
# question: He picked up his pace to a run, he wanted to do what? options: A: learn to walk B: frightened C: get away from D: exercise E: go faster
# Target Answer: E: go faster
# Predicted Answer: D: exercise
# question: What does everyone have in relation to other people? options: A: feelings B: food C: unique personality D: different standards E: values
# Target Answer: A: feelings
# Predicted Answer: C: unique personality
# question: What do you ask a child to do when you first meet her? options: A: ask questions B: count to ten C: costume D: state name E: dress herself
# Target Answer: D: state name
# Predicted Answer: E: dress herself
# question: Where can you store your dishes in your dwelling? options: A: drawer B: shelf C: pantry D: apartment E: cabinet
# Target Answer: B: shelf
# Predicted Answer: C: pantry
# question: The man laid on the soft moss and looked up at the trees, where was the man? options: A: niagra falls B: forest C: waterfall D: ground E: tree
# Target Answer: B: forest
# Predicted Answer: C: waterfall
# question: Where can I find a stapler in many places? options: A: desk drawer B: office building C: manual D: office supply store E: desktop
# Target Answer: B: office building
# Predicted Answer: D: office supply store
# question: Where would you find a toy soldier that is being played with? options: A: toy box B: movies C: child's hand D: toybos E: child park
# Target Answer: C: child's hand
# Predicted Answer: B: movies
# question: Batman bought beer. There were no bottles available. He had to settle for what?. options: A: shelf B: soccer game C: keg D: can E: refrigerator
# Target Answer: D: can
# Predicted Answer: C: keg
# question: Surprising an angry person could lead to what? options: A: humor B: fight C: jocose D: laughter E: accidents
# Target Answer: B: fight
# Predicted Answer: E: accidents
# question: Where is a dining area likely to be small? options: A: cruise ship B: home C: mall D: restaurant E: dark cave
# Target Answer: B: home
# Predicted Answer: A: cruise ship
# question: More people should lower the guard and just have fun, we don't got long just what? options: A: enjoy living B: happy C: enjoyable D: get laid E: do enjoy
# Target Answer: A: enjoy living
# Predicted Answer: D: get laid
# question: She was in an affair, what did that end upon discovery by her husband? options: A: relationship B: marriage C: fidelity D: love E: divorce
# Target Answer: B: marriage
# Predicted Answer: E: divorce
# question: What is the most famous constellation out of earth? options: A: one moon B: milky way C: god's creation D: stars E: universe
# Target Answer: B: milky way
# Predicted Answer: D: stars
# question: Sitting down quickly after eating beans could lead to what? options: A: flatulence B: happiness C: laziness D: fall asleep E: comfort
# Target Answer: A: flatulence
# Predicted Answer: D: fall asleep
# question: Where do people want to have a lot of coffee? options: A: table B: office C: desk D: kitchen E: ocean
# Target Answer: B: office
# Predicted Answer: D: kitchen
# question: It's Friday night and Alice puts off going to bed because she plans on doing what Saturday? options: A: hatred B: sleeping in C: rest D: making love E: insomnia
# Target Answer: B: sleeping in
# Predicted Answer: Sunday
# question: Where are you likely to find a Japanese restaurant not run by people from Japan? options: A: california B: downtown C: large town D: tokio E: china town
# Target Answer: A: california
# Predicted Answer: C: large town
# question: Animals who have hair and don't lay eggs are what? options: A: reproduce asexually B: males C: mammals D: attack E: ocean
# Target Answer: C: mammals
# Predicted Answer: B: males
# question: John was an aristocratic fox hunter. Where might he live? options: A: england B: new hampshire C: street D: arkansas E: north dakota
# Target Answer: B: new hampshire
# Predicted Answer: A: england
# question: Where is a grape likely to be being fed to someone else? options: A: field B: bathroom C: michigan D: minnesota E: painting
# Target Answer: E: painting
# Predicted Answer: C: michigan
# question: Some food can be stored at room temperature until you open it, then you should keep it in what? options: A: shop B: bookcase C: shelf D: refrigerators E: kitchen
# Target Answer: D: refrigerators
# Predicted Answer: C: shelf
# question: Where does one usually keep literature? options: A: books and magazines B: own home C: kitchen D: shelf E: meeting
# Target Answer: D: shelf
# Predicted Answer: B: own home
# question: WHat type of keyboard is made up of one or more pipe divisions? options: A: killing B: typewriter C: office D: terminal E: organ
# Target Answer: E: organ
# Predicted Answer: B: typewriter
# question: James needed smooth sandpaper, but instead he got what type? options: A: rough B: non smooth C: uneven D: plastic E: bumpy
# Target Answer: A: rough
# Predicted Answer: B: non smooth
# question: If I want to open a steakhouse, what should I get first? options: A: michigan B: florida C: wine D: texas E: building
# Target Answer: E: building
# Predicted Answer: A: michigan
# question: Sarah didn't like to play but she didn't want to be sedentary and bored, either, so she took up what? options: A: serious B: longplay C: musical D: eat cake E: doing nothing
# Target Answer: C: musical
# Predicted Answer: B: longplay
# question: Joe found spiders while checking something outside. What might that be? options: A: cupboard B: closet C: storage bag D: mail box E: garage
# Target Answer: D: mail box
# Predicted Answer: E: garage
# question: Most items in retail stores are what even when they are on sale? options: A: overpriced B: purchase C: expensive D: park E: buying
# Target Answer: A: overpriced
# Predicted Answer: C: expensive
# question: Brawn opened the curtains so that the sun could do what? options: A: dry clothes B: warm house C: warm room D: shine brightly E: get dark
# Target Answer: C: warm room
# Predicted Answer: D: shine brightly
# question: How might releasing energy that has built up feel? options: A: damage B: wonderful C: exhaustion D: orgasm E: lazy
# Target Answer: B: wonderful
# Predicted Answer: C: exhaustion
# question: Where might it be hard to get furniture to? options: A: apartment B: loft C: store D: rug E: stairs
# Target Answer: B: loft
# Predicted Answer: E: stairs
# question: A great teacher can be what when you are attending school? options: A: detention B: graduate C: follower D: inspiration E: boredom
# Target Answer: D: inspiration
# Predicted Answer: C: follower
# question: What would you do to a crime scene before asking a question? options: A: express information B: touch everything C: think D: give clue E: analyse
# Target Answer: E: analyse
# Predicted Answer: D: give clue
# question: Where would you go if you want to buy some clothes? options: A: mall B: grocery store C: grocery store D: shop E: supermarket
# Target Answer: A: mall
# Predicted Answer: B: grocery store
# question: Where is food likely to stay dry? options: A: etna B: cupboard C: oven D: stomach E: fridge
# Target Answer: B: cupboard
# Predicted Answer: C: oven
# question: The woman is watching television and trying to forget her day, what is her goal? options: A: entertainment B: falling asleep C: getting fat D: crying E: relaxation
# Target Answer: E: relaxation
# Predicted Answer: B: falling asleep
# question: While John Candy and Dan Aykroyd didn't run into a gazelle, you'd have to go where to see one? options: A: eastern hemisphere B: the city C: open plain D: television program E: great outdoors
# Target Answer: E: great outdoors
# Predicted Answer: C: open plain
# question: A beaver is know for building prowess, their supplies come from where? options: A: british columbia B: body of water C: wooded area D: pay debts E: zoo
# Target Answer: C: wooded area
# Predicted Answer: A: british columbi
# question: Going public about a common problem can gain what for a celebrity? options: A: wide acceptance B: a degree C: pain D: getting high E: press coverage
# Target Answer: A: wide acceptance
# Predicted Answer: E: press coverage
# question: The electricity went out and everyone was shrouded in darkness. They all remained in their seats, because it would have been dangerous to try to find there way out. Where mihgt they have been? options: A: opera B: concert C: basement D: bedroom E: grand canyon
# Target Answer: A: opera
# Predicted Answer: B: concert
# question: If it is Chrismas time what came most recently before? options: A: halloween B: summer C: easter D: kwaanza E: give gift
# Target Answer: A: halloween
# Predicted Answer: C: easter
# question: The criminal insisted he must do the crime to the bank teller, but she tried to convince him there were other ways in life and this was what? options: A: willing B: optional C: should not D: have to E: unnecessary
# Target Answer: E: unnecessary
# Predicted Answer: C: should not
# question: what do you fill with ink to write? options: A: squid B: fountain pen C: pencil case D: newspaper E: printer
# Target Answer: B: fountain pen
# Predicted Answer: E: printer
# question: He walked into the room and had a great shock, his friends had what him? options: A: expected B: wanting C: calm D: thundershock E: surprised
# Target Answer: E: surprised
# Predicted Answer: D: thundershock
# question: He wasn't the hugging type, even when he meet friend he'd just do what? options: A: have sex B: smile C: hug each other D: conversation E: handshake
# Target Answer: E: handshake
# Predicted Answer: C: hug each other
# question: If you were lost you might need a map, the best place to find one on the road is at any what? options: A: truck stop B: amusement park C: atlas D: mall E: gas station
# Target Answer: E: gas station
# Predicted Answer: A: truck stop
# question: Where would you put a net if you wanted to use it? options: A: sports B: fishing gear C: soccer game D: fishing boat E: badminton
# Target Answer: D: fishing boat
# Predicted Answer: B: fishing gear
# question: Where do cars usually travel at very high speeds? options: A: freeway B: road C: race track D: alley E: parking lot
# Target Answer: C: race track
# Predicted Answer: A: freeway
# question: What will you do if you do not want to settle in one place? options: A: walk B: agitate C: wander D: remove E: disturb
# Target Answer: C: wander
# Predicted Answer: D: remove
# question: Where would a person live that isn't in the metro area but still has good schools? options: A: woods B: bed C: suburbs D: rural E: neighborhood
# Target Answer: C: suburbs
# Predicted Answer: D: rural
# question: Jane works for the government as a senator, where does she spend a lot of time? options: A: capitol building B: everything C: washington d.c D: russia E: canada
# Target Answer: A: capitol building
# Predicted Answer: C: washington d.c
# question: What did the policemen do when they heard a cry from a distance? options: A: run away B: hurry along C: fine motorists D: direct traffic E: help
# Target Answer: E: help
# Predicted Answer: B: hurry along
# question: Where would I not want a fox? options: A: hen house B: english hunt C: mountains D: outside bedroom window E: england
# Target Answer: A: hen house
# Predicted Answer: C: mountains
# question: What do humans do to other humans after death? options: A: celebrate B: burial C: life D: rebirth E: decomposition
# Target Answer: B: burial
# Predicted Answer: A: celebrate
# question: Where can you go to use a piano in your neighborhood if you don't have one? options: A: music school B: music store C: neighbor's house D: lunch E: drawing room
# Target Answer: C: neighbor's house
# Predicted Answer: B: music store
# question: Where do most people turn to get information on their phones? options: A: internet B: book C: online D: google E: manual
# Target Answer: D: google
# Predicted Answer: A: internet
# question: What type of non-vegetarian soup is one likely to find a potato? options: A: beef stew B: own kitchen C: clam chowder D: kitchen cabinet E: pantry
# Target Answer: C: clam chowder
# Predicted Answer: A: beef stew
# question: They had a theory of what they could do in t he big game, so over and over they would what? options: A: park B: practice C: fact D: practical E: practise
# Target Answer: B: practice
# Predicted Answer: E: practise
# question: When you see something rise, you are where in relation to it? options: A: sun set B: near C: fall D: below E: lower
# Target Answer: D: below
# Predicted Answer: B: near
# question: What do you do when you need to get food? options: A: table B: disneyland C: refrigerators D: pantry E: shop
# Target Answer: E: shop
# Predicted Answer: D: pantry
# question: Where are bus stops more common in what parts? options: A: ocean B: getting off of bus C: airport D: urban area E: towns
# Target Answer: D: urban area
# Predicted Answer: E: towns
# question: Bill wanted to pick up a stranger, preferably a responsible one with kids. Where might he look for one? options: A: bus station B: paradise C: train station D: park E: sea
# Target Answer: D: park
# Predicted Answer: A: bus station
# question: By learning about the world, many poor college students gain what? options: A: pleasure B: greater mobility C: desire to travel D: global warming E: increased security
# Target Answer: C: desire to travel
# Predicted Answer: E: increased security
# question: John wanted to clean all of the dust out of his place before settling down to watch his favorite shows. What might he hardest do dust? options: A: closet B: under the bed C: television D: attic E: most buildings
# Target Answer: D: attic
# Predicted Answer: C: television
# question: Something had the nerve to break into the garbage last night, what did it? options: A: eyes B: animal C: fingertips D: brainstem E: human body
# Target Answer: B: animal
# Predicted Answer: C: fingertips
# question: Everybody seemed to be crying at the holy site, the tour guide explained that this was what? options: A: profane B: halibut C: damaged D: common E: halibut
# Target Answer: D: common
# Predicted Answer: A: profane
# question: The smile gave away that the what was one of happiness? options: A: manual B: rainbow C: cry D: frown E: make others happy too
# Target Answer: C: cry
# Predicted Answer: B: rainbow
# question: Where would a person live if they wanted no neighbors? options: A: housing estate B: neighborhood C: mars D: woods E: suburbs
# Target Answer: D: woods
# Predicted Answer: E: suburbs
# question: What happens to a dog before someone puts up posters of them? options: A: get lost B: require water C: trained D: bark E: roll over
# Target Answer: A: get lost
# Predicted Answer: D: bark
# question: Where are the most famous BBQ steakhouses in america? options: A: texas B: building C: kansas city D: maine E: falling down
# Target Answer: A: texas
# Predicted Answer: D: maine
# question: Where could there be a battle that involves words? options: A: court room B: war C: video game D: iraq E: church
# Target Answer: A: court room
# Predicted Answer: B: war
# question: The end of the barrel of what primitive firearm is bell shaped? options: A: barbell B: funnel C: blunderbuss D: wind instrument E: kettlebell
# Target Answer: C: blunderbuss
# Predicted Answer: E: kettlebell
# question: Many humans enjoy fishing and enjoy another relaxing activity at the same time, what activity is it? options: A: getting tied up lure. B: looking for information C: get wet D: drink beer E: sit quietly
# Target Answer: D: drink beer
# Predicted Answer: E: sit quietly
# question: Where would you get some maps that you own? options: A: bookstore B: library C: electrical circuit D: cabinet E: important when traveling
# Target Answer: D: cabinet
# Predicted Answer: A: bookstore
# question: A story about World War II would be set when? options: A: book or library B: book or magazine C: newspaper D: past E: future
# Target Answer: D: past
# Predicted Answer: E: future
# question: What is something children can do while traveling in a car? options: A: listen to music B: watch television C: play chess D: walk E: play basketball
# Target Answer: A: listen to music
# Predicted Answer: B: watch television
# question: Where would you hear a trumpet along with other instruments made from the same material? options: A: music store B: bass C: brass band D: orchestra E: marching band
# Target Answer: C: brass band
# Predicted Answer: D: orchestra
# question: The man took paperwork to other people to consult over it, where was he heading? options: A: desk B: meeting C: office D: table E: work
# Target Answer: B: meeting
# Predicted Answer: C: office
# question: Stark was just having fun, and he wasn't hurting anyone. What might have he been doing? options: A: painting his nails B: playing marbles C: constructing D: need for rest E: wild ride
# Target Answer: B: playing marbles
# Predicted Answer: C: constructing
# question: Where is a shelf likely to be hidden behind a door? options: A: refrigerator B: bookstore C: cupboard D: school building E: wardrobe
# Target Answer: C: cupboard
# Predicted Answer: D: school building
# question: The pitcher stepped on the mound ready to throw, where was he located specifically? options: A: hell B: baseball stadium C: golf course D: africa E: baseball diamond
# Target Answer: E: baseball diamond
# Predicted Answer: B: baseball stadium
# question: Where is a statute found on a platform? options: A: below B: arena C: concert hall D: museum E: building
# Target Answer: D: museum
# Predicted Answer: B: arena
# question: At the picnic she was stuck eating hamburger, she was worried because she forgot her chewables to prevent what? options: A: eat cake B: have fun C: food poisoning D: heartburn E: gain weight
# Target Answer: D: heartburn
# Predicted Answer: C: food poisoning
# question: For what entity should the government work? options: A: country B: democracy C: canada D: civilization E: tax office
# Target Answer: A: country
# Predicted Answer: B: democracy
# question: A potato is kept in the cellar, where is likely to be stored? options: A: farmer's market B: grocery bag C: pantry D: bushel basket E: fridge
# Target Answer: D: bushel basket
# Predicted Answer: E: fridge
# question: Where can you store you spare linens near your socks? options: A: hospital B: chest C: home D: dresser drawers E: cabinet
# Target Answer: D: dresser drawers
# Predicted Answer: B: chest
# question: To get clean clothes you to what to them? options: A: get dirty B: writing C: use water D: launder E: soap
# Target Answer: D: launder
# Predicted Answer: C: use water
# question: The person tried to reduce his weight with a shrink ray, but he got it backwards and only did what? options: A: grow B: gain weight C: make larger D: augment E: get bigger
# Target Answer: C: make larger
# Predicted Answer: B: gain weight
# question: If you wanted to show off silk, what item could it be on? options: A: jean B: mulberry tree C: garments D: expensive clothing E: parachutes
# Target Answer: D: expensive clothing
# Predicted Answer: A: jean
# question: Athletes soak in hot tubs to relieve what after playing baseball? options: A: fame B: errors C: pain D: strikes E: sore muscles
# Target Answer: E: sore muscles
# Predicted Answer: C: pain
# question: There's one obvious reason to eat vegetables, they're plain what you? options: A: lose weight B: good for C: bland D: chewing E: fibre
# Target Answer: B: good for
# Predicted Answer: C: bland
# question: What is the sun ultimately responsible for? options: A: earth warming B: sun tan C: light D: life on earth E: heat
# Target Answer: D: life on earth
# Predicted Answer: E: heat
# question: Where could a personal ficus live? options: A: cabin in the woods B: california C: front yard D: conservatory E: tropical forest
# Target Answer: C: front yard
# Predicted Answer: D: conservatory
# question: If the president wanted to ban snakes, where would he issue such a decree? options: A: street B: tropical forest C: garden of eden D: new mexico E: white house
# Target Answer: E: white house
# Predicted Answer: D: new mexico
# question: They were searching for rocks, so they missed the birds overhead as they stared at the what? options: A: ground B: drawer C: surface of earth D: pizza E: waterfall
# Target Answer: A: ground
# Predicted Answer: E: waterfall
# question: When you wipe you feet on the door mat and walk through the door where do you enter? options: A: a chair B: school C: living room D: doorway E: bathroom
# Target Answer: C: living room
# Predicted Answer: E: bathroom
# question: What can you use to store a book while traveling? options: A: library of congress B: pocket C: backpack D: suitcase E: synagogue
# Target Answer: D: suitcase
# Predicted Answer: C: backpack
# question: Where would you find gazelle under a G? options: A: open field B: ivory coast C: dictionary D: steppe E: encyclopedia
# Target Answer: E: encyclopedia
# Predicted Answer: A: open field
# question: What blocks sunshine? options: A: summer B: park C: desktop D: sea E: moon
# Target Answer: E: moon
# Predicted Answer: D: sea
# question: Where would you store a pillow case that is not in use? options: A: kitchen cupboard B: bedding store C: england D: drawer E: bedroom
# Target Answer: D: drawer
# Predicted Answer: A: kitchen cupboard
# question: If the kitten was going to grow up to be a mouser like it's mother, where should it spend most of it's time? options: A: shelter B: floor C: warm place D: farmhouse E: living room
# Target Answer: D: farmhouse
# Predicted Answer: E: living room
# question: Why would you take a bus to work? options: A: commute B: flying C: get somewhere D: travel E: go home
# Target Answer: A: commute
# Predicted Answer: C: get somewhere
# question: If you are hungry and going fishing, why would you be going fishing? options: A: to see the fish B: have fun C: catching fish D: wet clothes E: killing
# Target Answer: C: catching fish
# Predicted Answer: B: have fun
# question: What does a farmer need to do to make a maze on his farm in the fall? options: A: seed plants B: plant seeds C: garden D: grow corn E: produce food
# Target Answer: D: grow corn
# Predicted Answer: B: plant seeds
# question: For many males hair is a concern as they get older, it begins to what, causing a receding hairline? options: A: thin out B: grow in ear C: fall out D: bulge E: composted
# Target Answer: C: fall out
# Predicted Answer: A: thin out
# question: John loved his snake. It was the only ting he loved. He hated everyone else and was abrasive to most people, but he loved his snake. How might you describe the snake? options: A: sun itself B: tropical forest C: pet D: rude E: sharp
# Target Answer: C: pet
# Predicted Answer: E: sharp
# question: I picked from an apple tree outside of Fort Wayne, where am I? options: A: woods B: illinois C: indiana D: washington state E: tampa
# Target Answer: C: indiana
# Predicted Answer: E: tampa
# question: If you're celebrating with too many cocktails what may you have in the morning? options: A: drunkenness B: have fun C: headache D: hang over E: intimacy
# Target Answer: D: hang over
# Predicted Answer: A: drunkenness
# question: Where is the first place someone leaving the planet ends up? options: A: pay debts B: galaxy C: outer space D: orbit E: universe
# Target Answer: C: outer space
# Predicted Answer: D: orbit
# question: The town house went right to the curb, a slot effectively made a mailbox of the what? options: A: apartment building B: front door C: back door D: street corner E: porch
# Target Answer: B: front door
# Predicted Answer: D: street corner
# ...
# Target Answer: E: upwards
# Predicted Answer: D: upstream
# question: Joe's cat smelled something delicious and jumped into this, causing him to panic and fear for its life. Where might it have jumped? options: A: meat loaf B: bedroom C: microwave D: living room E: floor
# Target Answer: C: microwave
# Predicted Answer: E: floor
# question: James know that committing murder was wrong, but he thought that he could get away with it. He was really troubled and fearful because of what? options: A: happiness B: problems C: prosecution D: distress E: misery
# Target Answer: C: prosecution
# Predicted Answer: B: problems
# question: How can someone die from eating hamburger? options: A: gas B: getting full C: mad cow disease D: death E: feel full
# Target Answer: C: mad cow disease
# Predicted Answer: D: death
# question: Where would using a boat not require navigation skills? options: A: water B: ocean C: garage D: harbor E: river
# Target Answer: E: river
# Predicted Answer: B: ocean
# question: What does a self assured person often do? options: A: acknowledgment B: focused C: know what time D: feel important E: trust himself
# Target Answer: D: feel important
# Predicted Answer: E: trust himself
# question: He was very outgoing, for him making friends was no personal what? options: A: scary B: having friends C: good feeling D: conflict E: friendship
# Target Answer: D: conflict
# Predicted Answer: E: friendship
# question: What do you feel when giving assistance to the needy? options: A: reward B: boredom C: pleasure D: happiness E: satisfaction
# Target Answer: E: satisfaction
# Predicted Answer: C: pleasure
# question: Paul wants carrots and doesn't need to drive anywhere. He gets them from where? options: A: refrigerator B: store C: farmer's market D: supermarket E: dryer
# Target Answer: A: refrigerator
# Predicted Answer: B: store
# question: What does every person want? options: A: life partner B: larger house C: second chances D: money E: headache
# Target Answer: A: life partner
# Predicted Answer: B: larger house
# question: If a small flying animal picks up a string, where are they taking it? options: A: bird's nest B: park C: guitar D: kite E: quark
# Target Answer: A: bird's nest
# Predicted Answer: D: kite
# question: The weasel ran up away from danger, somebody joked only our first president could get him down from the what? options: A: washington dc B: ladder C: natural history museum D: cherry tree E: chicken coop
# Target Answer: D: cherry tree
# Predicted Answer: B: ladder
# question: George checked the rotor of the Apache, which wasn't powered by internal combustion, but by what? options: A: jet engine B: helicopter C: electric motor D: rotator E: electrical circuit
# Target Answer: A: jet engine
# Predicted Answer: C: electric motor
# question: Where is a salt shaker most often kept? options: A: cruet B: table setting C: kitchen cupboard D: cabinet E: store
# Target Answer: B: table setting
# Predicted Answer: C: kitchen cupboard
# question: Where would you put a dollar if you want to go to a store and buy something with it? options: A: cash drawer B: teh bank C: safety deposit box D: pocket E: piggy bank
# Target Answer: D: pocket
# Predicted Answer: A: cash drawer
# question: What room is likely to have a sideboard on the counter? options: A: home B: serve food buffet C: dining room D: living room E: kitchen
# Target Answer: E: kitchen
# Predicted Answer: D: living room
# question: What is unlikely to get bugs on its windshield due to bugs' inability to reach it when it is moving? options: A: airplane B: scooter C: motorboat D: car E: motor vehicle
# Target Answer: A: airplane
# Predicted Answer: E: motor vehicle
# question: What mall store sells jeans for a decent price? options: A: clothing store B: bedroom C: thrift store D: apartment E: gap
# Target Answer: E: gap
# Predicted Answer: C: thrift store
# question: Where can a bath towel be borrowed? options: A: cupboard B: at hotel C: swimming pool D: clothes line E: backpack
# Target Answer: B: at hotel
# Predicted Answer: C: swimming pool
# question: John rode on the plain until it reached the ocean and couldn't go any farther. What might he have bee on? options: A: mountain B: fancy C: sandplain D: cliff E: gorge
# Target Answer: D: cliff
# Predicted Answer: E: gorge
# question: They were never going to be big actors, but they all had passion for the local what? options: A: theater B: opera C: show D: television E: blockbuster feature
# Target Answer: A: theater
# Predicted Answer: B: opera
# question: Where would you use a folding chair but not store one? options: A: beach B: city hall C: closet D: garage E: school
# Target Answer: A: beach
# Predicted Answer: C: closet
# question: What does impeachment mean for the president? options: A: vote B: election C: trouble D: board room E: corporation
# Target Answer: C: trouble
# Predicted Answer: B: election
# question: What is main benefit to exercising? options: A: losing weight B: healthy C: get in shape D: weight loss E: sweat
# Target Answer: C: get in shape
# Predicted Answer: D: weight loss
# question: Steve thought that it was possible, but he agreed that it was what? options: A: no go B: unable C: unlikely D: impossibility E: cant do
# Target Answer: C: unlikely
# Predicted Answer: D: impossibility
# question: What region of a west coast U.S. city would you find a Japanese restaurant? options: A: california B: tokio C: downtown D: narnia E: large town
# Target Answer: C: downtown
# Predicted Answer: A: california
# question: What animal is known for being a follower? options: A: goat B: expensive C: lion D: wolf E: meadow
# Target Answer: A: goat
# Predicted Answer: C: lion
# question: The soldier was told to get to the rendezvous point, for there he was suppose to what? options: A: fight enemy B: go to war C: fight for freedom D: wait for orders E: follow instructions
# Target Answer: D: wait for orders
# Predicted Answer: B: go to war
# question: What was the man encouraged to do after he expressed his anger violently? options: A: cool off B: punch C: illustrate point D: fight E: release energy
# Target Answer: A: cool off
# Predicted Answer: E: release energy
# question: What do you need to do to use television if it is already turned on? options: A: get wet B: open eyes C: kill D: plug in E: first turn on power
# Target Answer: B: open eyes
# Predicted Answer: D: plug in
# question: The chief saw his entire tribe wiped out, he was a leader with a single what? options: A: peon B: indian C: minister D: follower E: employee
# Target Answer: D: follower
# Predicted Answer: A: peon
# question: Where would you find the sharpest parts of a triangle? options: A: three vertices B: point C: 3 sides D: three sides E: math book
# Target Answer: A: three vertices
# Predicted Answer: B: point
# question: What would it be if they get a surprising show over and over? options: A: surprise B: fight C: annoyance D: might scare E: irritated
# Target Answer: C: annoyance
# Predicted Answer: A: surprise
# question: The newlyweds began copulating their marriage, they wanted many what? options: A: babies B: odors C: sadness D: rapport E: ejaculation
# Target Answer: A: babies
# Predicted Answer: D: rapport
# question: Where could you find a shark before it was caught? options: A: pool hall B: tomales bay C: marine museum D: business E: desert
# Target Answer: B: tomales bay
# Predicted Answer: C: marine museum
# question: Where is one likely to find poker chips? options: A: supermarket B: pantry C: motherboard D: bar E: bar
# Target Answer: D: bar
# Predicted Answer: E: bar
# question: Dance can be elegant and specific, or you can just have fun and what? options: A: falling down B: trip C: fall down D: move around E: celebrate
# Target Answer: D: move around
# Predicted Answer: E: celebrate
# question: People played a variety of games in the soccer field. It was the closest thing they had to what? options: A: town B: beach C: park D: near E: outside
# Target Answer: C: park
# Predicted Answer: D: near
# question: How does going jogging generally affect one's self esteem? options: A: feel better B: feel pride C: sweating D: ocean E: arthritis
# Target Answer: A: feel better
# Predicted Answer: B: feel pride
# question: The buildings were intended to not have residential kitchens in them, what were they designed for? options: A: large city B: small C: eat cake D: university E: town
# Target Answer: D: university
# Predicted Answer: B: small
# question: Animals come in all types, some fly thanks to their lightweight hollow what? options: A: tails B: bones C: eyes D: heads E: bodies
# Target Answer: B: bones
# Predicted Answer: E: bodies
# question: The child felt like it was all pretend, he didn't understand what? options: A: people believe B: daydreams C: transcendentalism D: laughter E: religion
# Target Answer: E: religion
# Predicted Answer: A: people believe
# question: Where do apples form on an apple tree? options: A: south africa B: sunshine C: new york D: bloom E: trunk
# Target Answer: D: bloom
# Predicted Answer: E: trunk
# question: What can machines do that humans cannot? options: A: fail to work B: perform work C: answering questions D: see work E: fly
# Target Answer: E: fly
# Predicted Answer: B: perform work
# question: The place where my linen closet is really needs repainting a light color as it only has one overhead light. options: A: house B: home C: pool house D: hallway E: bedroom
# Target Answer: D: hallway
# Predicted Answer: E: bedroom
# question: Where is a bird likely to make it's home? options: A: forest B: nest C: roof D: leaves E: sky
# Target Answer: A: forest
# Predicted Answer: B: nest
# question: How would you express information if you do not have a pen or pencil? options: A: may disagree B: close mouth C: write down D: talk E: eyes
# Target Answer: D: talk
# Predicted Answer: C: write down
# question: Why does someone want to examine thing closely? options: A: buy B: learn about C: buy D: complex E: interesting
# Target Answer: B: learn about
# Predicted Answer: E: interesting
# question: What does drinking alcohol lead to? options: A: have fun B: intoxication C: vomiting D: drinking more alcohol E: nausea
# Target Answer: B: intoxication
# Predicted Answer: E: nausea
# question: What is the opposite of a little of something? options: A: much B: plenty C: more D: big E: lot of
# Target Answer: E: lot of
# Predicted Answer: A: much
# question: The princess was pure, the evil wizard wished to do what to her? options: A: dirty B: tarnish C: corrupt D: contaminated E: applied
# Target Answer: C: corrupt
# Predicted Answer: B: tarnish
# question: The piece of paper was worth a lot of money, it was an old Apple Inc what? options: A: notebook B: copy machine C: stock certificate D: ream E: thumb drive
# Target Answer: C: stock certificate
# Predicted Answer: D: ream
# question: If you own a cat where is the last place you'd want to find it? options: A: trouble B: dog's mouth C: backyard D: nature E: home
# Target Answer: B: dog's mouth
# Predicted Answer: E: home
# question: Where would you find a kosher deli along side a number of different places to eat? options: A: los angeles B: food court C: new york city D: jewish community E: jewish neighborhoods
# Target Answer: B: food court
# Predicted Answer: D: jewish community
# question: James loved to surf but he wasn't good at it. He would always do what? options: A: wipe out B: enjoy yourself C: start fighting D: get wet E: drown
# Target Answer: A: wipe out
# Predicted Answer: E: drown
# question: When did mammoth's live? options: A: boscage B: forest C: prehistory D: prehistoric times E: ancient times
# Target Answer: E: ancient times
# Predicted Answer: D: prehistoric times
# question: From where does a snowflake form? options: A: cloud B: snow storm C: billow D: air E: snowstorm
# Target Answer: A: cloud
# Predicted Answer: D: air
# question: Traveling from new place to new place is likely to be what? options: A: going somewhere B: exhilarating C: diarrhea D: relocation E: exhausting
# Target Answer: B: exhilarating
# Predicted Answer: E: exhausting
# question: Marathoners feel fatigued after running twenty six miles, but some that have pushed them self too hard might be prone to what? options: A: excruciating pain B: passing out C: death D: drunk E: exhaustion
# Target Answer: B: passing out
# Predicted Answer: E: exhaustion
# question: I am cold, what should I do to stay warm? options: A: stay in bed B: light fire C: freezer D: lay on ice E: spit
# Target Answer: B: light fire
# Predicted Answer: D: lay on ice
# question: What do audiences clap for? options: A: cinema B: theatre C: movies D: show E: hockey game
# Target Answer: D: show
# Predicted Answer: E: hockey game
# question: Who is not famous for a superhighway with no speed limit? options: A: europe B: germany C: industrialized country D: city E: america
# Target Answer: E: america
# Predicted Answer: B: germany
# question: The low trickle of water revealed a stone, where was the stone found? options: A: ocean B: gallbladder C: driveway D: river bed E: creek bed
# Target Answer: E: creek bed
# Predicted Answer: D: river bed
# question: What is a person considered a bully known for? options: A: ridiculous B: false information C: made fun of D: brain tumor E: bull rider
# Target Answer: C: made fun of
# Predicted Answer: B: false information
# question: There was a long cottage somewhere. People thought it was haunted. It was overgrown, there was nothing near it. It's was far into the what? options: A: mountains B: countryside C: train D: painting E: village
# Target Answer: B: countryside
# Predicted Answer: A: mountains
# question: What happens when driving? options: A: lack of fuel B: paint scratching C: wheels turning D: tire wear E: traffic accident
# Target Answer: C: wheels turning
# Predicted Answer: A: lack of fuel
# question: Why would one try to avoid work? options: A: making money B: leave home C: success D: malaise E: bad mood
# Target Answer: D: malaise
# Predicted Answer: E: bad mood
# question: What is another name for the color of the fur of a dog with light colored fur? options: A: fair B: basket C: dog hair D: game E: sun
# Target Answer: A: fair
# Predicted Answer: C: dog hair
# question: The lion sensed his competitor was timid, so what attitude did the lion take? options: A: reckless B: bellicose C: defensive D: aggressive E: dauntless
# Target Answer: D: aggressive
# Predicted Answer: B: bellicose
# question: At a shop what can you buy to put your spare unused things? options: A: basement B: cardboard box C: ocean floor D: high school E: container
# Target Answer: E: container
# Predicted Answer: B: cardboard box
# question: A person with digestion issues eats a meat-filled breakfast, what does he feel? options: A: heartburn B: overeating C: happiness D: being satisfied E: gain energy
# Target Answer: A: heartburn
# Predicted Answer: D: being satisfied
# question: David watched some nesting birds using his binoculars while on vacation. Where might David be?. options: A: sky B: vaccation C: forest D: countryside E: roof
# Target Answer: C: forest
# Predicted Answer: D: countryside
# question: Where would you find many varieties of plants including a rosebush? options: A: kew gardens B: garder C: backyard D: shop E: beautiful garden
# Target Answer: E: beautiful garden
# Predicted Answer: A: kew gardens
# question: What does a person with a what likely do? options: A: feel important B: trust himself C: own house D: electrical circuit E: know what time
# Target Answer: E: know what time
# Predicted Answer: D: electrical circuit
# question: What are cats often known for? options: A: whiskers B: sharp teeth C: purr D: four legs E: sharp claws
# Target Answer: E: sharp claws
# Predicted Answer: B: sharp teeth
# question: Tweed is a rare fabric in modern clothing, what brand should I look for when buying it? options: A: scotland B: brown C: fabric store D: clothing stores E: eddie bauer
# Target Answer: E: eddie bauer
# Predicted Answer: D: clothing stores
# question: If you really wanted a grape, where would you go to get it? options: A: winery B: fruit stand C: field D: kitchen E: food
# Target Answer: B: fruit stand
# Predicted Answer: A: winery

# %% [markdown]
# #### Evaluate the model fine-tuned on social_i_qa for 2 epochs

# %%
# Load the pretrained model
social_i_qa_model = T5ForConditionalGeneration.from_pretrained('./models/social_i_qa')
social_i_qa_tokenizer = T5Tokenizer.from_pretrained('./models/social_i_qa')

# %%
# Load the validation dataset
social_i_qa_valid_dataset = torch.load('./data/social_i_qa/valid_data.pt')
social_i_qa_dataloader = torch.utils.data.DataLoader(social_i_qa_valid_dataset, batch_size = 32)

# %%
# Generate predictions
social_i_qa_predictions = []
social_i_qa_targets = []
social_i_qa_model.to(device)    
social_i_qa_model.eval()
with torch.no_grad():
    for batch in tqdm(social_i_qa_dataloader):
        prediction = social_i_qa_model.generate(input_ids = batch['input_ids'].to(device), 
                          attention_mask = batch['attention_mask'].to(device),
                          max_length = 16)
        prediction = [social_i_qa_tokenizer.decode(ids) for ids in prediction]
        target = [social_i_qa_tokenizer.decode(ids) for ids in batch['target_ids']]
    
        social_i_qa_predictions.extend(prediction)
        social_i_qa_targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=62.0), HTML(value='')))

# %%
metrics.accuracy_score(social_i_qa_targets, social_i_qa_predictions)
# Out:
# 0.6371545547594678

# %%
incorrect_idxs = [i for i, prediction in enumerate(social_i_qa_predictions) if prediction != social_i_qa_targets[i]]
for incorrect_idx in incorrect_idxs:
    print(social_i_qa_tokenizer.decode(social_i_qa_valid_dataset[incorrect_idx]['input_ids']))
    print("Target Answer: {}".format(social_i_qa_tokenizer.decode(social_i_qa_valid_dataset[incorrect_idx]['target_ids'])))
    print("Predicted Answer: {}".format(social_i_qa_predictions[incorrect_idx]))
# Out:
# question: How would you describe Sydney? context: Sydney walked past a homeless woman asking for change but did not have any money they could give to her. Sydney felt bad afterwards. options: A: sympathetic B: like a person who was unable to help C: incredulous
# Target Answer: A: sympathetic
# Predicted Answer: B: like a person who was unable to help
# question: How would Jordan feel afterwards? context: Jordan was in charge of taking the food on the camping trip and left all the food at home. options: A: horrible that he let his friends down on the camping trip B: happy that he doesn't need to do the cooking on the trip C: very proud and accomplished about the camping trip
# Target Answer: A: horrible that he let his friends down on the camping trip
# Predicted Answer: C: very proud and accomplished about the camping trip
# question: How would you describe Aubrey? context: Aubrey never told Riley the answer and Riley was angry. options: A: rude B: smug at knowing the answer C: annoyed at Riley's response
# Target Answer: A: rude
# Predicted Answer: B: smug at knowing the answer
# question: Why did Kendall do this? context: Kendall's dog was overweight so they walked it five miles. options: A: because it was unhealthy B: start an exercise regimen C: because it looked good
# Target Answer: B: start an exercise regimen
# Predicted Answer: C: because it looked good
# question: What will happen to Carson? context: Carson kissed Alex gently on the cheek and asked to go to dinner. options: A: have a romantic meal B: go on a date C: loved
# Target Answer: B: go on a date
# Predicted Answer: A: have a romantic meal
# question: Why did Alex do this? context: Alex walked Robin towards the execution chamber for her last meal. options: A: work at the jail B: So Robin can eat C: release her
# Target Answer: A: work at the jail
# Predicted Answer: C: release her
# question: Why did Carson do this? context: Carson was excited to wake up to attend school. options: A: Take the big test B: Just say hello to friends C: go to bed early
# Target Answer: B: Just say hello to friends
# Predicted Answer: A: Take the big test
# question: What will Others want to do next? context: Sydney went trick or treating and the others joined him happily. options: A: go home B: did this to get candy C: get candy
# Target Answer: C: get candy
# Predicted Answer: A: go home
# question: How would Robin feel afterwards? context: Robin dried up the paper and lit it on fire and it blew away. options: A: happy their only photo blew away B: excited to see what comes next C: gone
# Target Answer: B: excited to see what comes next
# Predicted Answer: C: gone
# question: What will Robin want to do next? context: Due to his car breaking down, Robin decided to ride with Jan's friends to school. options: A: fix his car B: avoid missing class C: arrive on time to school
# Target Answer: A: fix his car
# Predicted Answer: C: arrive on time to school
# question: How would the parents feel as a result? context: Jordan taught art in elementary schools and was really great with his students. options: A: the art teacher B: concerned that Jordan will leave C: inspired to make their own art
# Target Answer: B: concerned that Jordan will leave
# Predicted Answer: C: inspired to make their own art
# question: What does Riley need to do before this? context: Riley had twisted their leg and began to hurt so bad that they could not walk. options: A: lie down B: run C: Sit and relax
# Target Answer: B: run
# Predicted Answer: A: lie down
# question: What does Taylor need to do before this? context: Taylor taught math in the schools after studying to be a teacher for four years. options: A: get a certificate B: teach small children C: work in a school
# Target Answer: A: get a certificate
# Predicted Answer: C: work in a school
# question: How would you describe Tracy? context: Tracy led their army and fought hard in the war until they sat upon the throne. options: A: peasant B: ruler C: powerful
# Target Answer: C: powerful
# Predicted Answer: B: ruler
# question: What will Kai want to do next? context: kai was bored and had nothing to do so he played card games. options: A: do math homework B: do nothing C: watch television
# Target Answer: C: watch television
# Predicted Answer: B: do nothing
# question: What will Robin want to do next? context: Robin changed Aubrey into clean clothes, so they can both go to the big play. options: A: wash the dirty laundry B: find clean clothes to wear C: entertained
# Target Answer: A: wash the dirty laundry
# Predicted Answer: B: find clean clothes to wear
# question: What will Others want to do next? context: Kendall wrapped string around my neck to measure the collar of a shirt. options: A: Measure other body parts B: Buy pants C: buy a shirt
# Target Answer: A: Measure other body parts
# Predicted Answer: C: buy a shirt
# question: How would you describe Carson? context: carson hated lee and his family so he took the risk to injure lee. options: A: carson who has hated lee B: as mean C: to risk injure lee
# Target Answer: B: as mean
# Predicted Answer: C: to risk injure lee
# question: What will happen to Jordan? context: Jordan was talking to a group of friends. Jordan talked behind Ash's back to fit in. options: A: lose a bet B: proud C: guilty
# Target Answer: C: guilty
# Predicted Answer: A: lose a bet
# question: What does Jordan need to do before this? context: jordan wanted to be nice to a girl so he took her to the shoe store. options: A: buy the girl some shoes B: ask the girl on a date C: be kind
# Target Answer: B: ask the girl on a date
# Predicted Answer: A: buy the girl some shoes
# question: How would Riley feel as a result of this? context: Robin shut Riley's eyes to the fact that he didn't want her to see the sex scene from the movie. options: A: scared of the scene B: like a baby C: protective of Riley
# Target Answer: B: like a baby
# Predicted Answer: A: scared of the scene
# question: How would you describe Cameron? context: Camerson was grading Bailey's research paper. Cameron felt satisfied with Bailey's work. options: A: honest B: a success as a teacher C: vengeful
# Target Answer: B: a success as a teacher
# Predicted Answer: A: honest
# question: What will Skylar want to do next? context: Skylar was pushed by the bully in the lunch line, so Skylar poured milk over their head. options: A: Run away B: Wait for a reaction C: wanted to fight with the bully
# Target Answer: A: Run away
# Predicted Answer: B: Wait for a reaction
# question: How would you describe Remy? context: Remy gave you Skylar account for netflix, so you wouldn't have to pay for your own account. options: A: feeling bored B: feeling loved C: cheated
# Target Answer: C: cheated
# Predicted Answer: B: feeling loved
# question: What will Skylar want to do next? context: Skylar was on the phone while at the national park. They lent little attention to the view. options: A: get Skylar off the phone B: sleep C: build
# Target Answer: A: get Skylar off the phone
# Predicted Answer: B: sleep
# question: Why did Sydney do this? context: Sydney works as a preschool teacher, and helped trace Robin's fingers. options: A: make popcorn B: teach her class the alphabet C: make artwork
# Target Answer: C: make artwork
# Predicted Answer: B: teach her class the alphabet
# question: What will Kendall want to do next? context: Kendall was really into house plants and often pour water in to jars so the fluoride would evaporate out. options: A: watered a few of the plants B: gather jars C: watered a few of her pets
# Target Answer: A: watered a few of the plants
# Predicted Answer: B: gather jars
# question: What will Casey want to do next? context: Aubrey was a police officer. She pulled Casey over for speeding in a construction zone. options: A: keep construction workers safe B: speed off C: make an excuse
# Target Answer: C: make an excuse
# Predicted Answer: B: speed off
# question: How would you describe Jordan? context: After being kicked out of the house by his parents, Jordan needed a place to live. options: A: quite lazy B: sad C: extremely hardworking
# Target Answer: B: sad
# Predicted Answer: C: extremely hardworking
# question: What will Alex want to do next? context: Alex was no longer raising Sasha but she did give birth to Sasha. options: A: build a relationship with Sasha B: Ask to visit Sasha C: Kidnap Sasha from home
# Target Answer: B: Ask to visit Sasha
# Predicted Answer: A: build a relationship with Sasha
# question: What will happen to Kendall? context: Sydney played Kendall's heart when she pretended to be interested in him at the party. options: A: be angry at Sydney B: be excited C: date Sydney
# Target Answer: A: be angry at Sydney
# Predicted Answer: B: be excited
# question: What will happen to Cameron? context: Cameron's parents told them to do well at school or they would be grounded. Cameron took their words seriously. options: A: listen or face severe punishment B: study very hard C: have his assignments done by their classmates
# Target Answer: B: study very hard
# Predicted Answer: A: listen or face severe punishment
# question: What does Quinn need to do before this? context: It was a pretty sunny day outside. Quinn walked instead. options: A: have fun B: notice the sun C: move their feet
# Target Answer: C: move their feet
# Predicted Answer: B: notice the sun
# question: What will Kai want to do next? context: Kai was grounded after wrecking his mother's car so he handed back the keys. options: A: wanted to stay out of trouble B: work hard at home C: rent out the car
# Target Answer: A: wanted to stay out of trouble
# Predicted Answer: B: work hard at home
# question: Why did Aubrey do this? context: But she didn't want to be on the team so walked off the court. options: A: wanted to spend more time at home B: wanted to win the championship C: Being on the team was her big dream
# Target Answer: A: wanted to spend more time at home
# Predicted Answer: C: Being on the team was her big dream
# question: What will Kendall want to do next? context: Kendall took their dog to the new dog park in the neighborhood. options: A: Give it a bath B: walk their dog C: meet other dog owners
# Target Answer: C: meet other dog owners
# Predicted Answer: B: walk their dog
# question: How would Robin feel afterwards? context: Robin's brother was hungry, too, so Robin cut the sandwich in half. options: A: accommodating B: Hungry C: friendly
# Target Answer: A: accommodating
# Predicted Answer: B: Hungry
# question: How would you describe Lee? context: Lee gave birth to ten babies over a span of ten years. options: A: barren B: caring C: would love her children
# Target Answer: C: would love her children
# Predicted Answer: B: caring
# question: What will Alex want to do next? context: Alex worshiped Jesus in their way even though everyone said it was the wrong way to do it. options: A: ale who has worshiped jesus B: be discouraged by others C: not listen to others
# Target Answer: C: not listen to others
# Predicted Answer: B: be discouraged by others
# question: How would Cameron feel afterwards? context: Cameron got a new video game and wanted to spend the night playing it. options: A: tired B: addicted to video games C: a gamer
# Target Answer: C: a gamer
# Predicted Answer: A: tired
# question: How would Alex feel afterwards? context: Alex grew closer to their significant other after they vacationed together. options: A: in love B: happy C: back from vacation
# Target Answer: A: in love
# Predicted Answer: B: happy
# question: How would you describe Riley? context: Riley regarded Jesse with observant eyes then smiled after they ate the last cookie. options: A: As talkative B: As silly C: like a person who was thoughtful
# Target Answer: B: As silly
# Predicted Answer: C: like a person who was thoughtful
# question: What will Quinn want to do next? context: Quinn cried their eyes out and ate a whole carton of icecream over her breakup. options: A: get back together with her boyrfrined B: purchase ice cream C: keep crying
# Target Answer: C: keep crying
# Predicted Answer: A: get back together with her boyrfrined
# question: What will Alex want to do next? context: Alex took care of the children after school so that their parents could continue to work. options: A: go home B: play games with the kids C: fight the parents
# Target Answer: B: play games with the kids
# Predicted Answer: A: go home
# question: What does Remy need to do before this? context: Remy went into town and found a fun place to get treats and ate some ice cream. options: A: settle down B: have excitement C: lock his house when leaving
# Target Answer: C: lock his house when leaving
# Predicted Answer: B: have excitement
# question: Why did Taylor do this? context: Taylor taught math in the schools and got a lot of praise for his style of teaching. options: A: loved B: continue teaching C: educate other teachers
# Target Answer: B: continue teaching
# Predicted Answer: C: educate other teachers
# question: Why did Cameron do this? context: Cameron left the Halloween party early and drove home as fast as they could. options: A: get home to a sick dog B: take the child to the doctor C: go to bed
# Target Answer: C: go to bed
# Predicted Answer: B: take the child to the doctor
# question: How would you describe Kendall? context: Kendall lost their shirt and walked around topless. options: A: ashamed B: embarassed C: in trouble
# Target Answer: B: embarassed
# Predicted Answer: C: in trouble
# question: Why did Taylor do this? context: Taylor got louder as they raised their voice because of the altercation. options: A: yell at them B: So people would ignore her C: be obnoxious
# Target Answer: A: yell at them
# Predicted Answer: C: be obnoxious
# question: How would you describe Sydney? context: Tom gave Sydney a red scarf. Sydney set it on fire. options: A: hot tempered B: angry at Tom C: bad that she had destroyed it
# Target Answer: A: hot tempered
# Predicted Answer: B: angry at Tom
# question: What does Austin need to do before this? context: Austin built a mall on the site where the ruins were found. options: A: bring a local attraction B: remove the artifacts C: find a new site
# Target Answer: B: remove the artifacts
# Predicted Answer: C: find a new site
# question: What will Cameron want to do next? context: Cameron arrived at the restaurant and sat at their table. options: A: learn about food B: order food C: eat
# Target Answer: B: order food
# Predicted Answer: C: eat
# question: How would you describe Jesse? context: Jesse is patient and hardworking and hungry in the morning. options: A: ill prepared B: Exhausted and starved C: thoughtful
# Target Answer: B: Exhausted and starved
# Predicted Answer: C: thoughtful
# question: Why did Ash do this? context: Ash and Sasha have been dating for a long time. options: A: get protection B: keep dating C: affectionate
# Target Answer: C: affectionate
# Predicted Answer: A: get protection
# question: What will Casey want to do next? context: Tracy understood Casey's mood better once they sat down and talked it out together. options: A: hug Tracy B: be mad at Tracy C: reach an understanding with Casey
# Target Answer: C: reach an understanding with Casey
# Predicted Answer: A: hug Tracy
# question: How would Others feel as a result? context: Bailey was a new student at the local high school in town. options: A: glad B: Excited to make new friends C: Nervous about her first day
# Target Answer: B: Excited to make new friends
# Predicted Answer: A: glad
# question: How would you describe Skylar? context: Skylar ate too much sweets and chocolate and drank too much sugary juice and the dentist told her she had a cavity. options: A: only eats sugar free foods B: disgusted C: has a sweet tooth
# Target Answer: C: has a sweet tooth
# Predicted Answer: B: disgusted
# question: What will happen to Riley? context: Riley had a lot of friends. options: A: they will play with Riley B: they will like Riley C: interacted outside the home a lot
# Target Answer: A: they will play with Riley
# Predicted Answer: C: interacted outside the home a lot
# question: Why did Sasha do this? context: Sasha grabbed Robins head and gave it a good shake. options: A: joke around B: bully C: better
# Target Answer: A: joke around
# Predicted Answer: C: better
# question: What does Jordan need to do before this? context: Jordan paid his debt to society by completing several hours of community service. options: A: volunteer to do community service B: commit a crime against society C: be a law-abiding citizen all the time
# Target Answer: B: commit a crime against society
# Predicted Answer: A: volunteer to do community service
# question: What will happen to Others? context: Aubrey met a creepy stranger at the park who was trying to get Aubrey to go home with them. options: A: be kidnapped B: want to stop the stranger C: be saved by police
# Target Answer: B: want to stop the stranger
# Predicted Answer: C: be saved by police
# question: What will Jan want to do next? context: Jan lit a fire under her coworkers because they wanted to start a fight. options: A: a trouble maker B: keep quiet C: get everyone angry
# Target Answer: C: get everyone angry
# Predicted Answer: B: keep quiet
# question: What will Casey want to do next? context: Casey ordered a package with priority shipping but two weeks passed and Casey never received the package. options: A: wait for the order B: make a complaint C: wait another week
# Target Answer: B: make a complaint
# Predicted Answer: C: wait another week
# question: What will Skylar want to do next? context: Skylar got a cast on her leg because they were in a car accident. options: A: lay in bed B: get into another accident C: better
# Target Answer: A: lay in bed
# Predicted Answer: C: better
# question: Why did Carson do this? context: Carson shook Jan's head again after she was very angry at him. options: A: ease the tension of the situation B: speak to Jan C: yell at Jan
# Target Answer: C: yell at Jan
# Predicted Answer: A: ease the tension of the situation
# question: Why did Remy do this? context: Remy left their money on a foreign bank account that was overseas. options: A: avoid taxes B: save the money C: hide the money
# Target Answer: A: avoid taxes
# Predicted Answer: B: save the money
# question: How would their friends feel as a result? context: Kendall showed off her new car to all of their friends. options: A: like they want to get one B: boastful C: proud
# Target Answer: A: like they want to get one
# Predicted Answer: C: proud
# question: What will Carson want to do next? context: Carson tried to fight Robin last night because Robin hurt Carson a lot. options: A: apologize B: do nothing C: hurt Robin
# Target Answer: C: hurt Robin
# Predicted Answer: A: apologize
# question: What will Jordan want to do next? context: Jordan left their book in the library after studying all day. options: A: Ask people if they've seen the book B: go home C: Go the library and hide the book
# Target Answer: A: Ask people if they've seen the book
# Predicted Answer: B: go home
# question: How would you describe Jesse? context: Jesse showed off her brand new car to Sydney's friends to make the jealous. options: A: upset B: generous C: conceited
# Target Answer: C: conceited
# Predicted Answer: B: generous
# question: What will Aubrey want to do next? context: Sydney gave Aubrey an estimate for how much their house is worth. options: A: show another house B: sell their house C: change their house
# Target Answer: B: sell their house
# Predicted Answer: A: show another house
# question: What will happen to Others? context: Austin just got a big bonus from the company. options: A: hungry B: work harder for the company C: receive more money from the company
# Target Answer: B: work harder for the company
# Predicted Answer: C: receive more money from the company
# question: What will happen to Riley? context: Riley was Jesse's girlfriend and had just found out Jesse was cheating on them. options: A: try to be friends with Jesse'd new girl B: hit Jesse and get arrested C: get dumped
# Target Answer: C: get dumped
# Predicted Answer: B: hit Jesse and get arrested
# question: Why did Remy do this? context: Remy was a hard worker at an insurance company. They were working late. options: A: get a job at an insurance company B: get rich C: receive an assignment to work on
# Target Answer: B: get rich
# Predicted Answer: A: get a job at an insurance company
# question: How would Riley feel afterwards? context: Rylie is teaching Sasha how to swim. Riley told Sasha to hold her breath. options: A: tired of teaching Sasha how to swim B: good about teaching Sasha to swim C: exhausted
# Target Answer: B: good about teaching Sasha to swim
# Predicted Answer: C: exhausted
# question: How would Quinn feel afterwards? context: Quinn moved into a new house after their old one burned down in a fire. options: A: like he lost everything B: like going back home C: practical
# Target Answer: A: like he lost everything
# Predicted Answer: C: practical
# question: What will Others want to do next? context: Riley was the best of friends with the boy and the others were relieved they had someone to lean on. options: A: talk with the boy B: relax about them next C: help the boy
# Target Answer: A: talk with the boy
# Predicted Answer: B: relax about them next
# question: How would Jan feel afterwards? context: Jan lit a fire under her coworkers for slacking off a lot. options: A: ashamed B: Dominant C: disgruntled
# Target Answer: B: Dominant
# Predicted Answer: C: disgruntled
# question: What will Others want to do next? context: Skylar entered the classroom at school and made fun of everyone for being there on time. options: A: tell skylar to keep it up B: try to dodge a late detention C: avoid skylar
# Target Answer: C: avoid skylar
# Predicted Answer: A: tell skylar to keep it up
# question: What does Riley need to do before this? context: Riley was on the beach near some birds that just flew away. They went after them. options: A: Follow the birds B: be able to move C: Watch the birds
# Target Answer: C: Watch the birds
# Predicted Answer: B: be able to move
# question: How would someone else feel as a result? context: Remy answered the question that was intended for someone else. options: A: very happy B: they were rude C: very smart
# Target Answer: B: they were rude
# Predicted Answer: A: very happy
# question: What will Quinn want to do next? context: Quinn was spending the day in the park with their friends. options: A: leave it B: go home C: catch the frisbee
# Target Answer: C: catch the frisbee
# Predicted Answer: B: go home
# question: How would you describe Taylor? context: Taylor asked the one officer for help in unlocking their car. options: A: a forgetful person B: a thoughtful person C: a trustworthy man
# Target Answer: A: a forgetful person
# Predicted Answer: B: a thoughtful person
# question: How would Austin feel afterwards? context: Carson was not exhibiting proper behavior in the military. Austin went ahead and discharged Carson of his duty. options: A: sad B: good C: proud
# Target Answer: A: sad
# Predicted Answer: C: proud
# question: What does Tracy need to do before this? context: Tracy gave it to their friend because they weren't going to need it anymore. options: A: Find the friend B: Ask why C: make sure their friend will want it
# Target Answer: C: make sure their friend will want it
# Predicted Answer: A: Find the friend
# question: How would Others feel as a result? context: Alex grew closer to their cousin and spent less time with the others. options: A: neglecting his friends B: ignored C: like they are close with their family
# Target Answer: B: ignored
# Predicted Answer: C: like they are close with their family
# question: How would you describe Quinn? context: While reading a story about animal abuse, Quinn felt a lot of pain. options: A: allergic B: sympathetic C: emotional
# Target Answer: B: sympathetic
# Predicted Answer: C: emotional
# question: What will happen to Sydney? context: Riley and Sydney are best friends, Riley sold Sydney's painting to the bidder after she stole it from her house. options: A: aweful she never expected this B: lie about it C: take the money
# Target Answer: A: aweful she never expected this
# Predicted Answer: C: take the money
# question: What does Sasha need to do before this? context: Sasha had gotten a tutor to help her with history. Sasha started to improve slowly. options: A: needed to be doing poorly B: needed to take a class C: thank the tutor
# Target Answer: A: needed to be doing poorly
# Predicted Answer: B: needed to take a class
# question: What does Tracy need to do before this? context: Tracy brought the kids to their dentist appointment, but it was scheduled during the school day. options: A: Keep the kids home from school until after their appointments B: Drop the kids off at school C: falsify time sheets
# Target Answer: A: Keep the kids home from school until after their appointments
# Predicted Answer: C: falsify time sheets
# question: What does Casey need to do before this? context: Casey's mother called Casey to tell her that she sent her a package by mail. options: A: check their mailbox B: have the package delivered by the post office C: open the package
# Target Answer: B: have the package delivered by the post office
# Predicted Answer: A: check their mailbox
# question: How would Aubrey feel afterwards? context: Aubrey was walking in the park one day. Aubrey met a stranger at the park when she stopped at the pond. options: A: anxious B: naive C: happy
# Target Answer: C: happy
# Predicted Answer: A: anxious
# question: How would Carson feel afterwards? context: Carson tried to fight Robin last night while they were at a bar. options: A: aggressive B: mean C: upset
# Target Answer: A: aggressive
# Predicted Answer: C: upset
# question: What will happen to Carson? context: Carson ate Bailey's candy and took a nice long nap after eating the candy. options: A: be upset B: indifferent C: proud
# Target Answer: B: indifferent
# Predicted Answer: C: proud
# question: How would you describe Jordan? context: Jordan felt bad after vandalizing a building so they paid their debt to society by cleaning up everything they had done. options: A: remorseful B: clear-minded C: proud
# Target Answer: A: remorseful
# Predicted Answer: B: clear-minded
# question: Why did Jan do this? context: Jan and their partner were going to a big new year's party at a bar downtown. Jan decided to leave the car keys at home and take a taxi. options: A: drink at the party B: take a taxi home C: avoid paying for parking
# Target Answer: A: drink at the party
# Predicted Answer: C: avoid paying for parking
# question: What will she want to do next? context: Lee challenged her to a fight by pointing his sword in her direction. options: A: get ready for battle B: pick up a sword C: put her sword away
# Target Answer: A: get ready for battle
# Predicted Answer: B: pick up a sword
# question: What will Others want to do next? context: Alex had been caught up in many crimes so one day Alex escaped to Mexico. options: A: avoid getting caught B: try to arrest Alex C: get away from trouble
# Target Answer: A: avoid getting caught
# Predicted Answer: B: try to arrest Alex
# question: What does Robin need to do before this? context: Robin let Carson explain to their parents what had happened at school. options: A: think Carson shouldn't explain B: be open C: think Carson should explain
# Target Answer: C: think Carson should explain
# Predicted Answer: B: be open
# question: Where will Casey take the children? context: Casey's children were playing in a park next to Jesse's house. options: A: continue playing B: avoid contact with Jesse C: make them safe
# Target Answer: A: continue playing
# Predicted Answer: C: make them safe
# question: What will Austin want to do next? context: Austin was having a great day and felt wonderful. options: A: scowl at a stranger B: smile at a stranger C: enjoy it too
# Target Answer: B: smile at a stranger
# Predicted Answer: C: enjoy it too
# question: What will Robin want to do next? context: Robin has been sick in the ER and Alex has been right there by her side but he had to leave to go to work. options: A: call someone else to come stay at the hospital with her B: visit after work C: stay by Alex's side when he gets home
# Target Answer: A: call someone else to come stay at the hospital with her
# Predicted Answer: C: stay by Alex's side when he gets home
# question: How would Others feel as a result? context: Aubrey wanted to go for an evening run since they were off from work. options: A: accomplished B: apprehension for Aubrey C: energized
# Target Answer: C: energized
# Predicted Answer: B: apprehension for Aubrey
# question: How would Riley feel afterwards? context: Riley was the best of friends with the boy next door. options: A: was relieved that his friend could give him a ride B:'s irritated that the boy bothers him all the time C: arrange a party for his best friend
# Target Answer: C: arrange a party for his best friend
# Predicted Answer: A: was relieved that his friend could give him a ride
# question: What will Sasha want to do next? context: The man commented inappropriately on the outfit that Sasha was wearing that day. options: A: walk away B: confront the man C: smile at the man
# Target Answer: A: walk away
# Predicted Answer: B: confront the man
# question: How would Kendall feel afterwards? context: Kendall kept the ball rolling on the project and was rewarded with a big bonus by the boss. options: A: persistent B: good C: bored
# Target Answer: B: good
# Predicted Answer: A: persistent
# question: What will happen to the mother? context: Jordan took their mother to the shoe store that she did not like going to. options: A: argue with his mother B: go to a different store C: scold Jordan
# Target Answer: C: scold Jordan
# Predicted Answer: B: go to a different store
# question: How would Sydney feel afterwards? context: Sydney played to Kendall's heart with the song they wrote for them. options: A: Good for thinking something nice B: Glad Kendall like's their song C: persuasive
# Target Answer: B: Glad Kendall like's their song
# Predicted Answer: C: persuasive
# question: How would Others feel as a result? context: Taylor is baby on the train. The train got stuck in a tunnel and Taylor began crying. As time went on, Taylor got louder. options: A: sympathetic B: be comforted C: being fussy
# Target Answer: A: sympathetic
# Predicted Answer: B: be comforted
# question: What does Ash need to do before this? context: Ash wanted his kids to understand why they were in trouble, so he got to the point. options: A: laugh with their kids B: punish their kids C: get their kids
# Target Answer: B: punish their kids
# Predicted Answer: C: get their kids
# question: What does Jordan need to do before this? context: Jordan had to walk home, but it was cold, so he walked home fast. options: A: wear a tshirt and shorts B: Get warm C: bundle up
# Target Answer: C: bundle up
# Predicted Answer: B: Get warm
# question: How would Tracy feel afterwards? context: tracy heard the news so she shook jan's head sadly. options: A: distraught B: sad C: angry
# Target Answer: B: sad
# Predicted Answer: A: distraught
# question: How would you describe Aubrey? context: Aubrey lived in Carson's environment, which was uncomfortable and filthy and something to be avoided. options: A: disgusted B: someone who has no food C: someone who has no options
# Target Answer: A: disgusted
# Predicted Answer: C: someone who has no options
# question: What will happen to Others? context: While at a Christmas party, Jan went into labor and gave birth to a daughter that day. options: A: Jan's friends put off the party and rushed her really fast to the hospital B: be happy C: hold their baby
# Target Answer: B: be happy
# Predicted Answer: A: Jan's friends put off the party and rushed her really
# question: How would you describe Austin? context: Austin always ate steak whenever he went out to a restaurant for food. options: A: full B: indecisive C: knowledgeable
# Target Answer: A: full
# Predicted Answer: C: knowledgeable
# question: Why did Austin do this? context: Austin got to warm to wear his sweater and decided to take it off. options: A: put the sweater down B: wanted to make a style statement C: forgot to wear pants and used a sweater instead
# Target Answer: A: put the sweater down
# Predicted Answer: B: wanted to make a style statement
# question: What will happen to Alex? context: Alex started going into labor, so she went to the hospital where she gave birth to Sasha. options: A: she will live a good life B: be happy C: she will be a baby
# Target Answer: B: be happy
# Predicted Answer: C: she will be a baby
# question: What will Jordan want to do next? context: Jordan was mentioned in Casey's chapter but the description of her wasn't very flattering. options: A: tell Casey what she thought of her B: Ask Casey to delete the chapter C: Ask Casey to autograph the book
# Target Answer: B: Ask Casey to delete the chapter
# Predicted Answer: A: tell Casey what she thought of her
# question: What will Remy want to do next? context: Remy was not supposed to do it, but he gave you Skylar's netflix account and pretended it was his own. options: A: get his own Netflix account B: cancel his Netflix account C: know a username
# Target Answer: A: get his own Netflix account
# Predicted Answer: B: cancel his Netflix account
# question: What will happen to Carson? context: Carson was wrongfully convicted for a crime. Taylor proved Carson's point last night and the judge agreed. options: A: be upset B: be released C: be rewarded
# Target Answer: B: be released
# Predicted Answer: A: be upset
# question: What will Skylar want to do next? context: Skylar got a cast on their arm after they went to the doctor. options: A: make an appointment with the doctor B: want to get better C: hurt their arm
# Target Answer: B: want to get better
# Predicted Answer: A: make an appointment with the doctor
# question: What will Bailey want to do next? context: Bailey held Aubrey's breath until she stopped breathing. options: A: run away B: let her friends see C: call the police
# Target Answer: A: run away
# Predicted Answer: C: call the police
# question: How would you describe Addison? context: Addison liked to go and pick apples. They got apples the other day. options: A: kind B: ruthless C: excited
# Target Answer: C: excited
# Predicted Answer: A: kind
# question: How would Alex feel afterwards? context: Alex knocked on wood after seeing a cat walk past him. options: A: reassured B: unlucky C: a paranoid person
# Target Answer: C: a paranoid person
# Predicted Answer: A: reassured
# question: How would Lee feel afterwards? context: Lee saved Kai's car from destruction by preventing a car accident. options: A: a careful driver with fast reflexes B: scared C: like he saved Kai
# Target Answer: A: a careful driver with fast reflexes
# Predicted Answer: C: like he saved Kai
# question: What would Bailey's boss think of Bailey? context: Bailey worked very hard on the company project and got a promotion at work. options: A: a hard worker B: tell their family and friends C: celebrate their promotion
# Target Answer: A: a hard worker
# Predicted Answer: C: celebrate their promotion
# question: Why did Sasha do this? context: Sasha had a plane to catch, so Sasha left the house within hours of waking up. options: A: travel patiently B: fly the plane C: miss the plane
# Target Answer: B: fly the plane
# Predicted Answer: A: travel patiently
# question: Why did Kendall do this? context: Kendall altered Lee's course. Lee was off on the wrong path at a young age. options: A: be a good leader B: be demanding C: change it
# Target Answer: A: be a good leader
# Predicted Answer: C: change it
# question: How would you describe Aubrey? context: Aubrey was stressed about losing out on the promotion. To relax, Aubrey swam in the pool. options: A: calm after swimming B: a person who prefers not to swim C: a person who likes to swim
# Target Answer: A: calm after swimming
# Predicted Answer: C: a person who likes to swim
# question: What will Ash want to do next? context: Sydney asked mom if Ash could have a dollar to buy candy for herself. options: A: borrow candy B: know Ash wanted candy C: be nice to the mom
# Target Answer: C: be nice to the mom
# Predicted Answer: A: borrow candy
# question: What will happen to Aubrey? context: Aubrey wanted to go in the pool but she was full of dirt. Robin went and changed Aubrey's clothes before she went swimming. options: A: have a good time B: have a bad time C: stay all dry
# Target Answer: A: have a good time
# Predicted Answer: B: have a bad time
# question: Why did Jordan do this? context: Jordan watched Alex's every look at the party he went to for school graduation. options: A: go to the party B: had heard she would be there and he wanted to flirt with her every chance he could get C: had heard she would be there and he wanted make sure she did not get bored at the party
# Target Answer: B: had heard she would be there and he wanted to flirt with
# Predicted Answer: C: had heard she would be there and he wanted make sure she
# question: How would Jesse feel afterwards? context: Jesse had been sick for several weeks, but after taking new medication, Jesse was feeling much better. options: A: healthy B: confident C: doing better
# Target Answer: A: healthy
# Predicted Answer: C: doing better
# question: How would Others feel as a result? context: Skylar sold homemade sculptures, and her family and friends bought them to be supportive. In a week's time all of the sculptures disintegrated into dust. options: A: happy B: sad C: cheated in the sale
# Target Answer: C: cheated in the sale
# Predicted Answer: B: sad
# question: How would Others feel as a result? context: Remy gave birth to a baby girl even though Remy thought they would have a boy. options: A: happy that they were not born a boy B: happy that they were born a girl C: as though they messed up by not being a boy
# Target Answer: B: happy that they were born a girl
# Predicted Answer: C: as though they messed up by not being a boy
# question: Why did Sydney do this? context: Sydney put on their clothes and the boys got ready for school. options: A: wanted the boys to be self-sufficient B: wanted the boys to loaf C: wanted to be a good mother
# Target Answer: C: wanted to be a good mother
# Predicted Answer: A: wanted the boys to be self-sufficient
# question: How would Tracy feel afterwards? context: Tracy had the world by the tail after she managed to do everything at work. options: A: sad B: sastisfied C: ambitious
# Target Answer: B: sastisfied
# Predicted Answer: C: ambitious
# question: How would Tracy feel afterwards? context: A big dog started chasing Tracy in the park so Tracy ran for their life to their car and jumped in to get away from the dog. options: A: A person who was panicking B: tranquility C: shocked
# Target Answer: A: A person who was panicking
# Predicted Answer: C: shocked
# question: How would Ash feel afterwards? context: Ash tried to redeem himself after he missed an open shot in the game. options: A: disappointed B: frugal C: trying hard
# Target Answer: A: disappointed
# Predicted Answer: C: trying hard
# question: What will Others want to do next? context: Addison kept their kids well behaved and taught them good manors. options: A: raise their kids to be good adults B: ask their kids to behave C: be well manored as well
# Target Answer: C: be well manored as well
# Predicted Answer: B: ask their kids to behave
# question: Why did Sasha do this? context: Sasha was working hard for a long time and wanted a break. They spent a weekend traveling. options: A: take a break B: enjoy it C: visit family
# Target Answer: A: take a break
# Predicted Answer: B: enjoy it
# question: Why did Jordan do this? context: Jordan was so good at painting portraits that they made it their career. options: A: Jordan's paintings sell for a lot of money B: open a gallery C: save for a house
# Target Answer: A: Jordan's paintings sell for a lot of money
# Predicted Answer: B: open a gallery
# question: Why did Addison do this? context: Addison was at the shop and picked up groceries the other day then drove them back home and put them in the frigdge and cupboards. options: A: Plan dinner B: was hungry C: Store the grocery bags
# Target Answer: A: Plan dinner
# Predicted Answer: B: was hungry
# question: What will Others want to do next? context: skylar went shopping with friends in order to buy expensive clothes even though their friends were poor. options: A: get something B: needed to have friends C: get nothing
# Target Answer: C: get nothing
# Predicted Answer: A: get something
# question: How would Riley feel afterwards? context: Riley began to hurt inside. options: A: happy B: Someone who needs help C: Painful
# Target Answer: B: Someone who needs help
# Predicted Answer: C: Painful
# question: What will happen to Carson? context: Carson's mother does not allow them to play video games. Carson's mother found out that Carson was at a friend's house playing video games. options: A: Carson's friend will ground them B: Carson's mother will scold them C: Others will be punished
# Target Answer: B: Carson's mother will scold them
# Predicted Answer: C: Others will be punished
# question: How would you describe Kai? context: Kai had some choice words to say but she decided to keep the language in check. options: A: intelligent B: ignorant C: like the better person for not engaging in the petty fight
# Target Answer: C: like the better person for not engaging in the petty fight
# Predicted Answer: A: intelligent
# question: What will Tracy want to do next? context: Tracy gave birth to Addison and was very proud of her new child that day. options: A: have a baby of her own B: proud C: experience motherhood for the first time
# Target Answer: C: experience motherhood for the first time
# Predicted Answer: A: have a baby of her own
# question: What will Addison want to do next? context: Addison and their friends were playing hide and seek at recess. Addison ran away to go find a hiding place. options: A: win the game of tag B: Come outside C: win the game of hide and seek
# Target Answer: C: win the game of hide and seek
# Predicted Answer: B: Come outside
# question: What does Bailey need to do before this? context: Bailey was a good basketball player who had a special shot in their arsenal. options: A: needed to do some stretching B: practice more C: needed to get drunk
# Target Answer: B: practice more
# Predicted Answer: A: needed to do some stretching
# question: How would you describe Sydney? context: Sydney set Skylar's phone on edge just a small hairline over falling over the desk. options: A: are reckless B: careless C: are boring
# Target Answer: B: careless
# Predicted Answer: A: are reckless
# question: Why did Alex do this? context: Alex loved to watch tv so he spent most of his time up in his room with it on. options: A: liked the feeling B: go to sleep C: hated the world
# Target Answer: C: hated the world
# Predicted Answer: A: liked the feeling
# question: How would Addison feel afterwards? context: Addison was listening to music very loudly. They turned their music down. options: A: a fan with bad hearing B: a fan of loud music C: satisfied
# Target Answer: B: a fan of loud music
# Predicted Answer: A: a fan with bad hearing
# question: How would you describe Jan? context: Jan said walk back to the students who were being disruptive and loud. options: A: a softy at heart B: Stop talking in mid-sentence and look in a non-aggressive way at the student making the noise C: no-nonsense
# Target Answer: C: no-nonsense
# Predicted Answer: B: Stop talking in mid-sentence and look in a non
# question: What will Sydney want to do next? context: Growing up, Sydney had always wanted to be a lawyer. So, when she got to college, she took school very seriously. Because of this, during her senior year she felt like she had a good chance at getting into law school. options: A: take the LSAT B: was a hard worker C: participate in a local election
# Target Answer: A: take the LSAT
# Predicted Answer: C: participate in a local election
# question: What will Sydney want to do next? context: Sydney woke up and was ready to start the day. They put on their clothes. options: A: go to bed B: go to the pool C: go to work
# Target Answer: C: go to work
# Predicted Answer: A: go to bed
# question: What does Ted need to do next? context: Aubrey and Ted was on a fishing trip when a shark hit the boat and Aubrey fell out of it. options: A: Ted was very shocked and scared and he started hollering at Aubrey to grab his hand to pull her out B: go to the boat C: Ted was very shocked and scared and he rowed away from the area of danger very quickly forgetting Aubrey
# Target Answer: A: Ted was very shocked and scared and he started holler
# Predicted Answer: B: go to the boat
# question: What will happen to Riley? context: Riley regarded Jesse, but Jesse was annoyed that they were being watched. options: A: anxious B: they will be slapped C: irritated
# Target Answer: B: they will be slapped
# Predicted Answer: C: irritated
# question: How would the others feel as a result? context: While everyone else stood around trying to figure out the instructions by themselves, Taylor gave help to a friend and they completed the task first. options: A: self-starting B: intrigued that they didn't tell all of them C: jealous that they didn't help all of them
# Target Answer: C: jealous that they didn't help all of them
# Predicted Answer: B: intrigued that they didn't tell all of them
# question: Why did Quinn do this? context: Quinn climbed into bed after a full, busy day of work. options: A: felt tired B: shut the lights off C: felt energized
# Target Answer: A: felt tired
# Predicted Answer: C: felt energized
# question: How would you describe Carson? context: Carson was a week away from finals, but went over his friends every day to play video game. options: A: not motivated B: disapproving C: focused on grades
# Target Answer: A: not motivated
# Predicted Answer: C: focused on grades
# question: Why did Remy do this? context: Remy challenged them to a game of racquetball at the local YMCA gym. options: A: was bored and decided to gather some people for a good game of racquetball B: was bored and decided to he wanted them to go to the gym and watch him not show C: win the game
# Target Answer: A: was bored and decided to gather some people for a good game
# Predicted Answer: C: win the game
# question: Why did it become dark outside? context: Remy and their friends were playing hide and seek in Remy's house. When they finished playing, it was very dark outside. options: A: go to sleep B: hid their friends and sought them for too long C: and their friends lost track of the time
# Target Answer: C: and their friends lost track of the time
# Predicted Answer: B: hid their friends and sought them for too long
# question: What will happen to Jesse? context: Riley regarded Jesse with gentle eyes before asking him out. options: A: accept the invitation next B: have a date C: get rejected
# Target Answer: A: accept the invitation next
# Predicted Answer: C: get rejected
# question: How would Others feel as a result? context: Sasha got revenge on the people who had stolen the car from her. options: A: quite elated B: furious at the perpetrators C: quite paid back
# Target Answer: C: quite paid back
# Predicted Answer: B: furious at the perpetrators
# question: How would you describe Skylar? context: Skylar got a cast on her leg after she broke it while skateboarding. options: A: athletic B: sad C: terrible
# Target Answer: B: sad
# Predicted Answer: A: athletic
# question: What will Tracy want to do next? context: Tracy took Jesse's students on a field trip because Jesse was not feeling well. options: A: take the students back to school B: drive the students back home C: know directions
# Target Answer: A: take the students back to school
# Predicted Answer: B: drive the students back home
# question: What will Alex want to do next? context: Alex was saving up for a new car. Alex sold books on amazon. options: A: buy more books on Amazon B: spend all the money on books C: save all the money from selling books
# Target Answer: C: save all the money from selling books
# Predicted Answer: A: buy more books on Amazon
# ...
# Target Answer: C: beloved
# Predicted Answer: A: prone to migraines
# question: What does Jordan need to do before this? context: After she graduated, Jordan would teach English in schools. options: A: forge her college transcripts to get a job interview B: start teaching sooner C: get an internship at the school to get more work experience
# Target Answer: C: get an internship at the school to get more work experience
# Predicted Answer: A: forge her college transcripts to get a job interview
# question: Why did Riley do this? context: Riley regarded Jesse with observant eyes to watch over the children at the daycare. options: A: trusts Jesse B: be alert and on point C: pay attention to everything that goes on
# Target Answer: B: be alert and on point
# Predicted Answer: A: trusts Jesse
# question: What will Jesse want to do next? context: Jesse got angry with Robin and set their car on fire. options: A: call the police B: escape the fire C: get revenge
# Target Answer: B: escape the fire
# Predicted Answer: A: call the police
# question: What will Carson want to do next? context: Carson shook Jan's head again looking to get the spine properly aligned after surgery. options: A: get angry with Jan B: feeling C: ignore Jan's pleas
# Target Answer: C: ignore Jan's pleas
# Predicted Answer: B: feeling
# question: What does Aubrey need to do before this? context: Aubrey has always been there for Alex. Aubrey fulfilled Alex's needs. options: A: loyal B: stay with Alex C: pay for Alex's bills
# Target Answer: B: stay with Alex
# Predicted Answer: A: loyal
# question: Why did Remy do this? context: Remy moved to a new city. They made more friends. options: A: travel to the new city B: pack their things C: wanted to influence people
# Target Answer: A: travel to the new city
# Predicted Answer: C: wanted to influence people
# question: What will happen to Robin? context: After rushing to make it to the gate, Robin missed his flight, so Cameron picked him up from the airport. options: A: be in a car B: pick up their friend C: be on a plane
# Target Answer: A: be in a car
# Predicted Answer: C: be on a plane
# question: What will Others want to do next? context: Sasha got revenge on her friends after they made a joke about her. options: A: be fair B: play with her C: hurt her back
# Target Answer: C: hurt her back
# Predicted Answer: A: be fair
# question: What does Tracy need to do before this? context: Tracy crossed the rubicon because they wanted to cross it and be the best. options: A: need to be the best B: keep working even if they fail C: need to be the worst
# Target Answer: B: keep working even if they fail
# Predicted Answer: A: need to be the best
# question: What will the students want to do next? context: Sydney guessed you could say that Sydney loved teaching and teaches chemistry. options: A: The students will report Sydney to the dean B: The students will all drop out of Sydney's class C: their favorite teacher
# Target Answer: C: their favorite teacher
# Predicted Answer: A: The students will report Sydney to the dean
# question: How would you describe Cameron? context: cameron was bored out of his mind so he left the show early. options: A: upset for wasting their money on the ticket B: fun C: as boring
# Target Answer: A: upset for wasting their money on the ticket
# Predicted Answer: C: as boring
# question: Why did Taylor do this? context: As the room filled and got louder, Taylor got louder. options: A: were obnoxious B: speak over the noise C: were mad
# Target Answer: B: speak over the noise
# Predicted Answer: A: were obnoxious
# question: How would you describe Taylor? context: After having it spoken discreetly to him, Taylor repeated the lord's request loudly for all to hear. options: A: considerate of the feelings of others B: rude in social situations C: evil
# Target Answer: B: rude in social situations
# Predicted Answer: A: considerate of the feelings of others
# question: What will Jan want to do next? context: Carson shook Jan's head again to wake her up after the accident. options: A: Check the girl for a pulse B: Call an ambulance C: Continue waking up
# Target Answer: C: Continue waking up
# Predicted Answer: B: Call an ambulance
# question: What will Cameron want to do next? context: Cameron moved Kendall's body because they didn't want anyone to see. options: A: escape B: admit to their crime C: they were being discreet
# Target Answer: A: escape
# Predicted Answer: B: admit to their crime
# question: How would Addison feel afterwards? context: Addison took long walks on the beach to lose weight. options: A: Well exercised B: dedicated to the goal C: Lazy
# Target Answer: B: dedicated to the goal
# Predicted Answer: A: Well exercised
# question: How would Others feel as a result? context: Cameron got to the restaurant and decided to order some pizza there. options: A: ready to order B: like dancing C: in the mood for italian food
# Target Answer: C: in the mood for italian food
# Predicted Answer: A: ready to order
# question: What will Cameron want to do next? context: Cameron drove nearly three hours so that he could pick Robin up from the nearest airport. options: A: Turn around and make the drive back again B: Leave and drive back the next day instead C: Stop in the airport to use the restroom
# Target Answer: C: Stop in the airport to use the restroom
# Predicted Answer: A: Turn around and make the drive back again
# question: What will Ash want to do next? context: Ash always performed better at his workplace after a warm cup of coffee. options: A: start a new task B: take some nyquil C: go home
# Target Answer: A: start a new task
# Predicted Answer: C: go home
# question: What will Bailey want to do next? context: Bailey passed Jesse an examination booklet after she decided not to study that subject anymore. options: A: give the booklet back to Bailey B: leave the class C: throw away the examination booklet
# Target Answer: B: leave the class
# Predicted Answer: A: give the booklet back to Bailey
# question: How would you describe Skylar? context: Skylar was outdoors in the wintertime and pulled the wool over their eyes and face. options: A: feeling cold B: wearing wool C: feeling warm
# Target Answer: A: feeling cold
# Predicted Answer: C: feeling warm
# question: What does Skylar need to do before this? context: Skylar distributed the data in several forms without double checking the figures. options: A: gather the data B: hand out the forms C: rush things
# Target Answer: C: rush things
# Predicted Answer: A: gather the data
# question: How would Aubrey feel as a result? context: Aubrey sounded good today considering they had been sick last week. options: A: they were grateful B: they were unhealthy C: elated that they are not sick
# Target Answer: C: elated that they are not sick
# Predicted Answer: A: they were grateful
# question: What does Jan need to do before this? context: Sasha was taking a train back to school, so Jan took Sasha to the station. options: A: check the train schedule B: make sure she get's on the train C: make sure she get's where she's going
# Target Answer: A: check the train schedule
# Predicted Answer: C: make sure she get's where she's going
# question: What does Jordan need to do before this? context: Jordan wanted to buy Kendall a birthday gift so they went to the pet store. options: A: Ask Kendall what they want B: Drive around till they find a pet store C: and Kendall are siblings
# Target Answer: A: Ask Kendall what they want
# Predicted Answer: B: Drive around till they find a pet store
# question: Why did Taylor do this? context: taylor recruited kai into his cult and filled his mind with ideas. options: A: ask Kai if they have any friends B: help kai out C: be selfish
# Target Answer: C: be selfish
# Predicted Answer: B: help kai out
# question: How would Tracy feel afterwards? context: Tracy crossed the rubicon with her pack and equipment. options: A: Tired B: Full of energy C: outdoorsy
# Target Answer: A: Tired
# Predicted Answer: C: outdoorsy
# question: How would Sasha feel as a result? context: Taylor invited Sasha to join Riley at the county fair this weekend. options: A: friendly B: Wanted C: thoughtful
# Target Answer: A: friendly
# Predicted Answer: B: Wanted
# question: How would Sasha feel afterwards? context: Sasha got very tired, so she took a nap. options: A: exhausted B: energetic C: more tired
# Target Answer: B: energetic
# Predicted Answer: A: exhausted
# question: How would Remy feel afterwards? context: Remy started to dance because he had been drinking. options: A: humiliated B: Embarassed C: Fun loving
# Target Answer: C: Fun loving
# Predicted Answer: A: humiliated
# question: What does Riley need to do before this? context: Riley screamed in pain as the person across from them smashed their fists into Riley. options: A: need to do nothing B: need to sit still C: need to try to escape
# Target Answer: A: need to do nothing
# Predicted Answer: C: need to try to escape
# question: What will Others want to do next? context: Riley went out to the club with some friends excited for the weekend. options: A: get dressed for the club B: ask his friends if they are trying to go clubbing C: Stay up really late
# Target Answer: C: Stay up really late
# Predicted Answer: A: get dressed for the club
# question: What does Kai need to do before this? context: Kai studied all day and finished her homework first. options: A: Take a nap B: sharpen her pencils C: Class to submitted to homework first
# Target Answer: B: sharpen her pencils
# Predicted Answer: C: Class to submitted to homework first
# question: How would Alex feel afterwards? context: Alex looked it up online when she couldn't find the information in a book. options: A: like a fool B: clueless C: smart
# Target Answer: C: smart
# Predicted Answer: B: clueless
# question: What will Casey want to do next? context: Casey called Aubrey's parents and wanted to find out information on Aubrey's birthday. options: A: want revenge on Aubrey's parents B: treat Aubrey C: throw Aubrey a party
# Target Answer: C: throw Aubrey a party
# Predicted Answer: B: treat Aubrey
# question: What will Alex want to do next? context: As it was part of his duties, Alex carried Robin into the execution. options: A: help Robin get free B: secured for execution C: wanted to perform honorably
# Target Answer: B: secured for execution
# Predicted Answer: A: help Robin get free
# question: How would Tracy's friends feel as a result? context: Tracy went out with their friends and Tracy decided to pay for their entire bill for everyone. options: A: that Tracy won't want to pay for anything again B: a big spender C: that Tracy acted unselfishly
# Target Answer: C: that Tracy acted unselfishly
# Predicted Answer: B: a big spender
# question: What will happen to Others? context: Jan decided to quit their job to get a better job as a banker. options: A: enjoy having a better job B: think of them well C: want them to succeed
# Target Answer: C: want them to succeed
# Predicted Answer: A: enjoy having a better job
# question: What will happen to Austin? context: Austin was feeling generous after getting a big bonus at work, so Austin took the family out to dinner. options: A: pay for a fancy dinner B: The others will repay the favor C: be in trouble with the family
# Target Answer: A: pay for a fancy dinner
# Predicted Answer: B: The others will repay the favor
# question: How would Jordan feel afterwards? context: Looking to get away from the crowd, Jordan ran quickly. options: A: would be extremely calm B: would still be anxious C: full of energy
# Target Answer: B: would still be anxious
# Predicted Answer: C: full of energy
# question: Why did Quinn do this? context: Remy and Quinn were having an affair, and then Remy's wife found out. options: A: get Remy's wife out of the picture B: let everyone know about the affair C: get Remy's husband out of the picture
# Target Answer: A: get Remy's wife out of the picture
# Predicted Answer: B: let everyone know about the affair
# question: What does Robin need to do before this? context: Robin was on a long road trip and had to stop by a gas station. Robin got out of the car and pumped their gas. options: A: park the car B: light a cigarette C: have a full gas tank
# Target Answer: A: park the car
# Predicted Answer: C: have a full gas tank
# question: How would Robin feel as a result? context: Alex left Robin and told her to never call him again. options: A: upset with each other B: distant from each other C: regretted
# Target Answer: B: distant from each other
# Predicted Answer: C: regretted
# question: What will happen to Taylor after the fact? context: Taylor had gotten very drunk and pissed on Jesse's bonfire. options: A: yell at taylor B: taken aside so that they can sober up C: beaten up by Jesse's other friends
# Target Answer: B: taken aside so that they can sober up
# Predicted Answer: C: beaten up by Jesse's other friends
# question: How would Collin feel as a result? context: Casey put food where Collin had been sitting because he got up to go to the bathroom. options: A: sneaky B: funny C: angry
# Target Answer: A: sneaky
# Predicted Answer: B: funny
# question: What will Cameron want to do next? context: Cameron leaved early in the morning so he could get their on time. options: A: get a good amount of sleep B: leave later than he should C: speed when driving
# Target Answer: C: speed when driving
# Predicted Answer: A: get a good amount of sleep
# question: What does Sydney need to do before this? context: Sydney appointed a detective to investigate the string of robberies. options: A: ignore the problem B: hire someone C: look into the robberies
# Target Answer: C: look into the robberies
# Predicted Answer: B: hire someone
# question: How would you describe Robin? context: Robin was rushing and took their class test quickly. options: A: finish quickly B: worried C: anxious
# Target Answer: C: anxious
# Predicted Answer: A: finish quickly
# question: What will Others want to do next? context: Alex and his cohorts, the former criminal masterminds for the Lupino family, made their escape from jail. options: A: Bribe the guards B: contact the FBI C: Plan the escape
# Target Answer: B: contact the FBI
# Predicted Answer: C: Plan the escape
# question: How would you describe Kai? context: Kai was swinging the bat without paying attention and swung through the posts. options: A: Angry B: Cautious C: Think about that swing
# Target Answer: C: Think about that swing
# Predicted Answer: A: Angry
# question: How would you describe Riley? context: Riley was competing in a gymnastics meet. Riley felt worse after she lost. options: A: competitive B: upset C: regretful
# Target Answer: B: upset
# Predicted Answer: A: competitive
# question: How would Others feel as a result? context: Jordan found out that they were very ill, but they made light of the ailment. options: A: feeling sad B: Humorous C: Uncomfortable
# Target Answer: C: Uncomfortable
# Predicted Answer: B: Humorous
# question: How would you describe Ash? context: Ash was late to the movie theater and missed her date out with friends. options: A: has a habit of being on time B: does not care about about other people's plans C: does not have a phone to call other people
# Target Answer: B: does not care about about other people's plans
# Predicted Answer: A: has a habit of being on time
# question: What will Austin want to do next? context: Austin was an intern and so he worked without pay. options: A: drop the internship and live in a van B: continue working as an intern forever C: find a job that pays them a wage
# Target Answer: C: find a job that pays them a wage
# Predicted Answer: B: continue working as an intern forever
# question: How would Kendall feel afterwards? context: Kendall was watching a friend's dog. Kendall didn't know anything about the dog. options: A: like they are confident they can do it B: good with animals C: that they should ask their friend what to do
# Target Answer: C: that they should ask their friend what to do
# Predicted Answer: A: like they are confident they can do it

# %% [markdown]
# #### Evaluate the model fine-tuned on common_gen for 1 epoch

# %%
# Load the pretrained model
common_gen_model = T5ForConditionalGeneration.from_pretrained('./models/common_gen')
common_gen_tokenizer = T5Tokenizer.from_pretrained('./models/common_gen')

# %%
# Load the validation dataset
common_gen_valid_dataset = torch.load('./data/common_gen/valid_data.pt')
common_gen_dataloader = torch.utils.data.DataLoader(common_gen_valid_dataset, batch_size = 32)

# %%
common_gen_predictions = []
common_gen_targets = []
common_gen_model.to(device)    
common_gen_model.eval()
with torch.no_grad():
    for batch in tqdm(common_gen_dataloader):
        prediction = common_gen_model.generate(
            input_ids = batch["input_ids"].to(device),
            attention_mask = batch["attention_mask"].to(device),
            num_beams = 5,
            length_penalty = 0.6,
            max_length = 32 + 2,  # +2 from original because we start at step=1 and stop before max_length
            #min_length = 1 + 1,  # +1 from original because we start at step=1
            no_repeat_ngram_size = 2,
            early_stopping = True
        )
        prediction = [common_gen_tokenizer.decode(ids, skip_special_tokens=True, clean_up_tokenization_spaces=False) for ids in prediction]
        target = [common_gen_tokenizer.decode(ids) for ids in batch['target_ids']]
        
        common_gen_predictions.extend(prediction)
        common_gen_targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))

# %%
common_gen_predictions[0:100]
# Out:
# ['A man stands in a field looking up.',
#  'A man stands in a field looking up.',
#  'A man stands in a field looking up.',
#  'A man stands in a field looking up.',
#  'A kid is dancing in a room.',
#  'A kid is dancing in a room.',
#  'A kid is dancing in a room.',
#  'A kid is dancing in a room.',
#  'A cat is petting on a couch.',
#  'A cat is petting on a couch.',
#  'A cat is petting on a couch.',
#  'A cat is petting on a couch.',
#  'A man climbs the side of a building.',
#  'A man climbs the side of a building.',
#  'A man climbs the side of a building.',
#  'A man climbs the side of a building.',
#  'A man climbs a wall and talks to someone.',
#  'A man climbs a wall and talks to someone.',
#  'A man climbs a wall and talks to someone.',
#  'A man climbs a wall and talks to someone.',
#  'A car driving in the snow.',
#  'A car driving in the snow.',
#  'A car driving in the snow.',
#  'A car driving in the snow.',
#  'A woman is wearing a phone to talk to someone.',
#  'A woman is wearing a phone to talk to someone.',
#  'A woman is wearing a phone to talk to someone.',
#  'a team plays hockey on the rink',
#  'a team plays hockey on the rink',
#  'a team plays hockey on the rink',
#  'a team plays hockey on the rink',
#  'A surfer is surfing in the ocean.',
#  'A surfer is surfing in the ocean.',
#  'A surfer is surfing in the ocean.',
#  'A man jumps down a flight of stairs.',
#  'A man jumps down a flight of stairs.',
#  'A man jumps down a flight of stairs.',
#  'A man jumps down a flight of stairs.',
#  'musicians playing instruments in a band',
#  'musicians playing instruments in a band',
#  'musicians playing instruments in a band',
#  'musicians playing instruments in a band',
#  'A man sits in a circle and talks.',
#  'A man sits in a circle and talks.',
#  'A man sits in a circle and talks.',
#  'A man sits in a circle and talks.',
#  'A man moves his eyes and looks at a man.',
#  'A man moves his eyes and looks at a man.',
#  'A man moves his eyes and looks at a man.',
#  'A man moves his eyes and looks at a man.',
#  'A man looks out the window and watches.',
#  'A man looks out the window and watches.',
#  'A man looks out the window and watches.',
#  'A man looks out the window and watches.',
#  'athlete prepares to run',
#  'athlete prepares to run',
#  'athlete prepares to run',
#  'athlete prepares to run',
#  'A man walks in a park wearing gear.',
#  'A man walks in a park wearing gear.',
#  'A man walks in a park wearing gear.',
#  'A man walks in a park wearing gear.',
#  'A man gives a speech on stage.',
#  'A man gives a speech on stage.',
#  'A man gives a speech on stage.',
#  'A man gives a speech on stage.',
#  'A woman rubs a hand with soap.',
#  'A woman rubs a hand with soap.',
#  'A woman rubs a hand with soap.',
#  'A woman rubs a hand with soap.',
#  'A man waves his hand in front of a man.',
#  'A man waves his hand in front of a man.',
#  'A man waves his hand in front of a man.',
#  'A man waves his hand in front of a man.',
#  'A man mows the lawn in his yard.',
#  'A man mows the lawn in his yard.',
#  'pottery on a wheel created',
#  'pottery on a wheel created',
#  'pottery on a wheel created',
#  'pottery on a wheel created',
#  'A man sits on a sofa holding his hand.',
#  'A man sits on a sofa holding his hand.',
#  'A man sits on a sofa holding his hand.',
#  'A man sits on a sofa holding his hand.',
#  'A man sits holding a newspaper.',
#  'A man sits holding a newspaper.',
#  'A man sits holding a newspaper.',
#  'A man sits holding a newspaper.',
#  'A woman looks at her hair and sits down.',
#  'A woman looks at her hair and sits down.',
#  'A woman looks at her hair and sits down.',
#  'A woman looks at her hair and sits down.',
#  'A man climbs a mountain with his equipment.',
#  'A man climbs a mountain with his equipment.',
#  'A man climbs a mountain with his equipment.',
#  'A man climbs a mountain with his equipment.',
#  'A man sits in a space and stares.',
#  'A man sits in a space and stares.',
#  'A man sits in a space and stares.',
#  'A man sits in a space and stares.']

# %%
common_gen_targets[0:100]
# Out:
# ['The player stood in the field looking at the batter.',
#  'The coach stands along the field, looking at the goalkeeper.',
#  'I stood and looked across the field, peacefully.',
#  'Someone stands, looking around the empty field.',
#  'The silly kid loves to dance in her room.',
#  'the dance kid room is full of kids',
#  'A kid is dancing in the room.',
#  'A group of kids are dancing around a living room.',
#  'A pet cat likes to sleep on a couch.',
#  'My pet cat love to sleep on the couch.',
#  'The woman pet the cat that was sat on the couch.',
#  'actor petting long haired gray cat on couch',
#  'The mouse climbed the side of the building.',
#  'I climbed the side of the building.',
#  'A girl climbs up the side of a building.',
#  'ivy climbs the side of a building.',
#  'The woman thats talking teaches her students how to climb the wall.',
#  'The person climbed up the wall to talk to the man.',
#  'The man talked about how to climb walls.',
#  'A man is talking in front of a climbing wall.',
#  'The car drove through the snow.',
#  "The woman couldn't drive her car in the snow.",
#  'The car drove threw the snow.',
#  'driving a car in snow',
#  'The boy wants to wear earpods as he talks on his phone.',
#  'I continued to talk on phone while wearing my shoes.',
#  'A man wearing glasses talking on a phone',
#  'The team practiced hockey at the outdoor rink.',
#  'The team plays hockey on the rink.',
#  'The hockey team practiced in the ice rink.',
#  'Two teams are playing hockey in a hockey rink.',
#  'the ocean is where surfers go to surf',
#  'The boy went to the ocean to surf and after awhile became a full blown surfer.',
#  'A surfer surfing in the ocean.',
#  'A boy jumps up a flight of stairs taking two at a time.',
#  'The boys jump down the flight of stairs.',
#  'A lady had to jump up the stairs so she wouldnt miss her flight.',
#  'A dog jumps down a flight of stairs.',
#  'The school band played their instruments in unison rendering a sweet music.',
#  'Bands use instruments to make music.',
#  'The band brought their instruments so they could play music.',
#  'A band playing some music with their instruments.',
#  'The students sit in a circle as the teacher talks.',
#  'We sat in a circle and talked.',
#  'We sat in a circle and talked.',
#  'Four young males sitting in a circle talking.',
#  'I quickly moved back, while still looking into the eyes of the stranger.',
#  'My eye moves around looking for the bird.',
#  'The eyes move to look around.',
#  'A woman looks at the camera and moves her eyes individually.',
#  'He looked at his watch and then out of the window.',
#  'The young girl looks out the window to watch the snow fall.',
#  'The cat was looking out the window watching the people.',
#  'Two people looking out the window watching radars.',
#  'The athlete performs stretches as they prepare to run.',
#  'The athlete prepares to run the race.',
#  'The athlete is preparing to run the 1000 metre track race.',
#  'An athlete prepare to run.',
#  'The hiker bought new gear to wear for the walk to the waterfall.',
#  'The hiker has lots of gear to wear while walking.',
#  'A man wears a backpack with hiking gear as he walks to the trail.',
#  'A person wearing gear walking in the snow.',
#  'The man on stage is giving a speech.',
#  'The mayor is giving a speech on the stage.',
#  'The man gave a speech on the stage.',
#  'A man on a stage giving a speech.',
#  'A man rubs his hands with soap after using the bathrooom.',
#  'I will now rub the soap on my dirty hand.',
#  'Rub the soap in your hand.',
#  'The person uses soap to rub vigorously the hands.',
#  'A girl waved her hand in front of the man.',
#  'front hand always used to bet the wave',
#  'The men in front waved hands.',
#  'kids waving hands in front of a cake.',
#  'David had to mow the lawn by 12:00pm, and there are a yard to finish.',
#  'The man is mowing the lawn in a yard.',
#  'Create pottery with a wheel and clay.',
#  'I create pottery on a wheel.',
#  'A pottery wheel can be used to create bowls.',
#  'A man is using a wheel to create pottery.',
#  'The sofa will sit in the living room and will hold visitors who visit.',
#  'Sit on the sofa and hold a pose.',
#  'A man holds a remote control while sitting on a sofa.',
#  'A man sitting on a sofa holding a baby.',
#  'the man sat down holding the newspaper.',
#  'The man was holding a newspaper as he sat in a chair.',
#  'The man held a newspaper while looking for a place to sit.',
#  'A man sitting on a bus is holding a newspaper.',
#  'The girl sits as she looks in the mirror while styling her hair.',
#  'When you sit in front of the mirror you can look at your hair.',
#  'hair look sit on the top',
#  'A girl with hair sits at a table looking around.',
#  'use the equipment to climb the mountain',
#  'The man uses climbing equipment to scale the mountain.',
#  'Got to have the right equipment to climb the mountain.',
#  'A man without equipment is climbing a mountain.',
#  'The kid wanted to sit in the empty space and stare at the wall.',
#  'I sit on the ground and stare off into space.',
#  'The boy went to sit by the window at night to stare outside into space.',
#  'Someone sits staring miserably into space.']

# %%
input_ids = common_gen_valid_dataset[0:100]['input_ids']
[common_gen_tokenizer.decode(ids) for ids in input_ids]
# Out:
# ['generate sentence: field look stand',
#  'generate sentence: field look stand',
#  'generate sentence: field look stand',
#  'generate sentence: field look stand',
#  'generate sentence: kid room dance',
#  'generate sentence: kid room dance',
#  'generate sentence: kid room dance',
#  'generate sentence: kid room dance',
#  'generate sentence: cat pet couch',
#  'generate sentence: cat pet couch',
#  'generate sentence: cat pet couch',
#  'generate sentence: cat pet couch',
#  'generate sentence: climb building side',
#  'generate sentence: climb building side',
#  'generate sentence: climb building side',
#  'generate sentence: climb building side',
#  'generate sentence: climb wall talk',
#  'generate sentence: climb wall talk',
#  'generate sentence: climb wall talk',
#  'generate sentence: climb wall talk',
#  'generate sentence: drive snow car',
#  'generate sentence: drive snow car',
#  'generate sentence: drive snow car',
#  'generate sentence: drive snow car',
#  'generate sentence: talk wear phone',
#  'generate sentence: talk wear phone',
#  'generate sentence: talk wear phone',
#  'generate sentence: hockey rink team',
#  'generate sentence: hockey rink team',
#  'generate sentence: hockey rink team',
#  'generate sentence: hockey rink team',
#  'generate sentence: ocean surfer surf',
#  'generate sentence: ocean surfer surf',
#  'generate sentence: ocean surfer surf',
#  'generate sentence: stair jump flight',
#  'generate sentence: stair jump flight',
#  'generate sentence: stair jump flight',
#  'generate sentence: stair jump flight',
#  'generate sentence: band music instrument',
#  'generate sentence: band music instrument',
#  'generate sentence: band music instrument',
#  'generate sentence: band music instrument',
#  'generate sentence: sit talk circle',
#  'generate sentence: sit talk circle',
#  'generate sentence: sit talk circle',
#  'generate sentence: sit talk circle',
#  'generate sentence: eye move look',
#  'generate sentence: eye move look',
#  'generate sentence: eye move look',
#  'generate sentence: eye move look',
#  'generate sentence: look watch window',
#  'generate sentence: look watch window',
#  'generate sentence: look watch window',
#  'generate sentence: look watch window',
#  'generate sentence: athlete prepare run',
#  'generate sentence: athlete prepare run',
#  'generate sentence: athlete prepare run',
#  'generate sentence: athlete prepare run',
#  'generate sentence: walk wear gear',
#  'generate sentence: walk wear gear',
#  'generate sentence: walk wear gear',
#  'generate sentence: walk wear gear',
#  'generate sentence: stage give speech',
#  'generate sentence: stage give speech',
#  'generate sentence: stage give speech',
#  'generate sentence: stage give speech',
#  'generate sentence: soap rub hand',
#  'generate sentence: soap rub hand',
#  'generate sentence: soap rub hand',
#  'generate sentence: soap rub hand',
#  'generate sentence: hand front wave',
#  'generate sentence: hand front wave',
#  'generate sentence: hand front wave',
#  'generate sentence: hand front wave',
#  'generate sentence: mow yard lawn',
#  'generate sentence: mow yard lawn',
#  'generate sentence: create pottery wheel',
#  'generate sentence: create pottery wheel',
#  'generate sentence: create pottery wheel',
#  'generate sentence: create pottery wheel',
#  'generate sentence: hold sofa sit',
#  'generate sentence: hold sofa sit',
#  'generate sentence: hold sofa sit',
#  'generate sentence: hold sofa sit',
#  'generate sentence: hold sit newspaper',
#  'generate sentence: hold sit newspaper',
#  'generate sentence: hold sit newspaper',
#  'generate sentence: hold sit newspaper',
#  'generate sentence: sit look hair',
#  'generate sentence: sit look hair',
#  'generate sentence: sit look hair',
#  'generate sentence: sit look hair',
#  'generate sentence: mountain climb equipment',
#  'generate sentence: mountain climb equipment',
#  'generate sentence: mountain climb equipment',
#  'generate sentence: mountain climb equipment',
#  'generate sentence: space stare sit',
#  'generate sentence: space stare sit',
#  'generate sentence: space stare sit',
#  'generate sentence: space stare sit']
