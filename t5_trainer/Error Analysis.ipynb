# %% [markdown]
# # Error Analysis

# %%
import pickle 
import torch
import nlp
from transformers import T5ForConditionalGeneration, T5Tokenizer
from tqdm.auto import tqdm
from sklearn import metrics
device = 'cuda' if torch.cuda.is_available else 'cpu'

# %% [markdown]
# ## Models to evaluate
#
# 1. **T5 Base**: Finetuned Commonsense QA for 10 epochs
# 2. **T5 Base + Social I QA**: Finetuned on Social I QA (4 epochs, batch 8, lr 1e-4), then finetuned on Commonsense QA (10 epochs, batch size 8, learning rate 1e-4, wu 0)
# 3. **T5 Base + Cosmos QA**: Finetuned on Cosmos QA (3 epochs, batch size 8, learning rate 5e-5), then finetuned on Commonsense QA (10 epochs, batch size 8, learning rate = 5e-5)
# 4. **T5 Base + hellaswag**:

# %%
# Load the validation dataset. Common to all analyses.
valid_dataset = torch.load('./data/commonsense_qa/valid_data.pt')
dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size = 32)

# %%
def predict_results(model_and_tokenizer_location):
    # Load the pretrained model
    model = T5ForConditionalGeneration.from_pretrained(model_and_tokenizer_location)
    tokenizer = T5Tokenizer.from_pretrained(model_and_tokenizer_location)

    # Generate predictions
    predictions = []
    targets = []
    model.to(device)    
    model.eval()
    with torch.no_grad():
        for batch in tqdm(dataloader):
            prediction = model.generate(input_ids = batch['input_ids'].to(device), 
                              attention_mask = batch['attention_mask'].to(device),
                              max_length = 16)
            prediction = [tokenizer.decode(ids) for ids in prediction]
            target = [tokenizer.decode(ids) for ids in batch['target_ids']]

            predictions.extend(prediction)
            targets.extend(target)
            
    return(predictions, targets, tokenizer)

# %%
class Answers:
    
    def __init__(self, predictions, targets, tokenizer):
        self.accuracy = metrics.accuracy_score(targets, predictions)
        
        # Find index of wrong answers 
        self.incorrect_idxs = [i for i, prediction in enumerate(predictions) 
                               if prediction != targets[i]]
        
        self.qq={}
        self.target_ans={}
        self.predicted_ans={}
        
        self.size = 0
        
        for incorrect_idx in self.incorrect_idxs:
            self.qq[incorrect_idx]           = tokenizer.decode(valid_dataset[incorrect_idx]['input_ids'] )
            self.target_ans[incorrect_idx]    = tokenizer.decode(valid_dataset[incorrect_idx]['target_ids'])
            self.predicted_ans[incorrect_idx] = predictions[incorrect_idx]
            self.size += 1
            
        self.get_error_df()
        
    def get_example(self, incorrect_idx):
        print(incorrect_idx, "-", self.qq[incorrect_idx].replace("options:", "\n\noptions:")\
             .replace("A:", "\nA:")\
             .replace("B:", "\nB:")\
             .replace("C:", "\nC:")\
             .replace("D:", "\nD:")\
             .replace("E:", "\nE:"))
        print("\n==> Correct ans:  ",   self.target_ans[incorrect_idx])
        print("==> Predicted ans:", self.predicted_ans[incorrect_idx])
        
    def get_error_df(self):
        drows=[]
        for idx in self.incorrect_idxs:
            drow=[]
            drow.append(idx)
            drow.extend(self.qq[idx]\
                 .replace("A:", "\nA:")\
                 .replace("B:", "\nB:")\
                 .replace("C:", "\nC:")\
                 .replace("D:", "\nD:")\
                 .replace("E:", "\nE:").split("\n"))
            drow.append(self.target_ans[idx])
            drow.append(self.predicted_ans[idx])
            drows.append(drow)

        self.error_df = pd.DataFrame(drows, 
                                     columns=["idx", "question", 
                                              "A", "B", "C", "D", "E", 
                                              "target", "predicted"]).set_index("idx")

# %% [markdown]
# ## T5 Base
#
# For Sonali to pickle and provide

# %%
modeldir = ""
t5_base_ans = Answers(predict_results(modeldir))
with open('t5_base_ans', 'wb') as f:
    pickle.dump(t5_base_ans, f)

# %% [markdown]
# ## T5 Base + Hella SWAG
#
# For Sonali to pickle and provide

# %%
modeldir = ""
t5_hel_ans = Answers(predict_results(modeldir))
with open('t5_hel_ans', 'wb') as f:
    pickle.dump(t5_hel_ans, f)

# %% [markdown]
# ## T5 Base + Cosmos QA

# %%
modeldir = "./models/cs_on_cosmos/batch_8_lr_5e-5_wu_0_epochs10"
t5_cos_predictions, t5_cos_targets, t5_cos_tokenizer = predict_results(modeldir)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=39.0), HTML(value='')))

# %%
t5_cos_ans = Answers(t5_cos_predictions, t5_cos_targets, t5_cos_tokenizer)

# %%
t5_cos_ans.size
# Out:
# 454

# %%
t5_cos_ans.incorrect_idxs[0:10]
# Out:
# [0, 2, 4, 9, 10, 16, 17, 19, 22, 23]

# %%
t5_cos_ans.get_example(2)
# Out:
# 2 - question: Where would you find magazines along side many other printed works?
#
# options:
# A: doctor
# B: bookstore
# C: market
# D: train station
# E: mortuary
#
# ==> Predicted ans: C: market
# ==> Correct ans:   B: bookstore

# %%
with open('t5_cos_ans', 'wb') as f:
    pickle.dump(t5_cos_ans, f)

# %% [markdown]
# ## T5 base + Social I QA

# %%
modeldir = "./models/cs_on_social/4_epochs_nonstop_batch8_lr1e-4_cs_10_e_b8_1e-4_wu0_300cp"
t5_so_predictions, t5_so_targets, t5_so_tokenizer = predict_results(modeldir)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=39.0), HTML(value='')))

# %%
t5_so_ans = Answers(t5_so_predictions, t5_so_targets, t5_so_tokenizer)

# %%
t5_so_ans.size
# Out:
# 465

# %%
t5_so_ans.incorrect_idxs[0:10]
# Out:
# [0, 4, 5, 9, 10, 16, 17, 19, 20, 22]

# %%
t5_so_ans.get_example(0)
# Out:
# 0 - question: A revolving door is convenient for two direction travel, but it also serves as a security measure at a what?
#
# options:
# A: bank
# B: library
# C: department store
# D: mall
# E: new york
#
# ==> Predicted ans: D: mall
# ==> Correct ans:   A: bank

# %%
with open('t5_so_ans', 'wb') as f:
    pickle.dump(t5_so_ans, f)

# %% [markdown]
# ## Data load

# %%
import pickle

# %%
with open("t5_so_ans", 'rb') as f:
    t5_so_ans = pickle.load(f)
    
t5_so_ans.get_error_df()

# %%
t5_so_ans.size
# Out:
# 465

# %%
from random import sample

# %%
max(t5_so_ans.error_df.index)
# Out:
# 1215

# %%
t5_so_ans.error_df.shape
# Out:
# (465, 8)

# %%
with open("t5_cos_ans", 'rb') as f:
    t5_cos_ans = pickle.load(f)
    
t5_cos_ans.get_error_df()

# %%
t5_cos_ans.size
# Out:
# 454

# %%
t5_cos_ans.error_df.shape
# Out:
# (454, 8)

# %%
t5_cos_ans.error_df.loc[sample(t5_cos_ans.incorrect_idxs, 100)]
# Out:
#                                                question                    A  \
# idx
# 648   question: The pencil sharpener was broken in t...             A: home
# 1010  question: If a small flying animal picks up a ...      A: bird's nest
# 10    question: What would vinyl be an odd thing to ...            A: pants
# 212   question: Where do you go on a night out befor...    A: new york city
# 1074  question: What would it be if they get a surpr...         A: surprise
# ...                                                 ...                  ...
# 275   question: What has a surface with many sides? ...      A: tetrahedron
# 245   question: The fact that Joe was able to memori...            A: awake
# 1024  question: Where can a bath towel be borrowed? ...         A: cupboard
# 875   question: What do geese do every fall in field...      A: guard house
# 899   question: If a person is using a computer to t...  A: program created
#
#                       B                     C                               D  \
# idx
# 648         B: library   C: stationery store                      D: cabinet
# 1010           B: park             C: guitar                         D: kite
# 10    B: record albums       C: record store                       D: cheese
# 212       B: las vegas         C: restaurant                    D: nightclub
# 1074          B: fight          C: annoyance                  D: might scare
# ...                 ...                   ...                             ...
# 275          B: object   C: geometry problem                         D: lake
# 245          B: repeat           C: sleeping                  D: concentrate
# 1024       B: at hotel      C: swimming pool                 D: clothes line
# 875             B: fly                C: eat   D: follow ultralight airplane
# 899          B: stress          C: happiness                        D: ocean
#
#                       E             target         predicted
# idx
# 648      E: desk drawer         B: library    E: desk drawer
# 1010           E: quark     A: bird's nest           D: kite
# 10         E: wallpaper       E: wallpaper  B: record albums
# 212             E: park      C: restaurant      D: nightclub
# 1074       E: irritated       C: annoyance       A: surprise
# ...                 ...                ...               ...
# 275         E: triangle     A: tetrahedron       E: triangle
# 245       E: read aloud           A: awake    D: concentrate
# 1024        E: backpack        B: at hotel  C: swimming pool
# 875   E: group together  E: group together            B: fly
# 899         E: headache       C: happiness         B: stress
#
# [100 rows x 8 columns]

# %%
t5_cos_ans.error_df.loc[sample(t5_cos_ans.incorrect_idxs, 100)].to_csv("t5_cos_ans_errors.csv")
t5_so_ans.error_df.loc[sample(t5_so_ans.incorrect_idxs, 100)].to_csv("t5_so_ans_errors.csv")

# %%
counter = 0

for soc_idx in t5_so_ans.incorrect_idxs:
    if soc_idx in t5_cos_ans.incorrect_idxs:
        counter += 1
        
counter
# Out:
# 368

# %% [markdown]
# Between the Social IQA model and the Cosmos QA model, they share 368 questions that they got wrong.

# %%
counter = 0

while counter <= 10:
    for soc_idx in t5_so_ans.incorrect_idxs:
        if soc_idx not in t5_cos_ans.incorrect_idxs:
            print(t5_so_ans.get_example(soc_idx))
            counter += 1
# Out:
# 5 - question: What island country is ferret popular?
#
# options:
# A: own home
# B: north carolina
# C: great britain
# D: hutch
# E: outdoors
#
# ==> Correct ans:   C: great britain
# ==> Predicted ans: B: north carolina
# None
# 20 - question: What could go on top of wood?
#
# options:
# A: lumberyard
# B: synagogue
# C: floor
# D: carpet
# E: hardware store
#
# ==> Correct ans:   D: carpet
# ==> Predicted ans: C: floor
# None
# 48 - question: What is a place that usually does not have an elevator and that sometimes has a telephone book?
#
# options:
# A: at hotel
# B: kitchen
# C: library
# D: telephone booth
# E: house
#
# ==> Correct ans:   E: house
# ==> Predicted ans: C: library
# None
# 66 - question: He was beginning to regret taking the fight when he saw how what his opponent was?
#
# options:
# A: fun
# B: joy
# C: satisfaction
# D: confident
# E: pride
#
# ==> Correct ans:   D: confident
# ==> Predicted ans: C: satisfaction
# None
# 75 - question: If you are awaking multiple times throughout the night because a lot is on your mind, what is a likely cause?
#
# options:
# A: irritability
# B: depression
# C: getting out of bed
# D: happiness
# E: discomfort
#
# ==> Correct ans:   B: depression
# ==> Predicted ans: A: irritability
# None
# 102 - question: When learning about the world and different cultures, what is important if you are committed to eliminating preconceived notions
#
# options:
# A: newness
# B: loss of innocence
# C: enlightenment
# D: open mind
# E: smartness
#
# ==> Correct ans:   D: open mind
# ==> Predicted ans: A: newness
# None
# 106 - question: Seafood restaurants are used to draw tourists where?
#
# options:
# A: maine
# B: shoe shop
# C: city
# D: boston
# E: coastal cities
#
# ==> Correct ans:   E: coastal cities
# ==> Predicted ans: C: city
# None
# 143 - question: Bob's only light source was a small bulb. There were four walls, if there was a door he couldn't see it. What was Bob in?
#
# options:
# A: closed room
# B: sky
# C: dard
# D: his grave
# E: house
#
# ==> Correct ans:   A: closed room
# ==> Predicted ans: E: house
# None
# 144 - question: James thought of criminal justice like a computer program. It need to work right. What ideas might James not like?
#
# options:
# A: manual
# B: process information
# C: power down
# D: control model
# E: reason exists
#
# ==> Correct ans:   D: control model
# ==> Predicted ans: E: reason exists
# None
# 153 - question: In order to learn to program from another person you can do what?
#
# options:
# A: learn how to
# B: have a friend
# C: knowledge
# D: take class
# E: have computer
#
# ==> Correct ans:   D: take class
# ==> Predicted ans: B: have a friend
# None
# 177 - question: What is a person called who doesn't have immortality?
#
# options:
# A: mortal
# B: dying
# C: death
# D: dead
# E: mortal
#
# ==> Correct ans:   E: mortal
# ==> Predicted ans: A: mortal
# None
# 183 - question: What kind of tale might feature a talking weasel?
#
# options:
# A: mulberry bush
# B: animated film
# C: chicken coop
# D: history book
# E: children's story
#
# ==> Correct ans:   E: children's story
# ==> Predicted ans: B: animated film
# None
# 200 - question: A loud machine is irritating, but many are expected where?
#
# options:
# A: museum
# B: house
# C: laboratory
# D: library
# E: industrial area
#
# ==> Correct ans:   E: industrial area
# ==> Predicted ans: C: laboratory
# None
# 202 - question: What happens if someone kisses too long?
#
# options:
# A: strong feelings
# B: herpes
# C: shortness of breath
# D: excitement
# E: arousal
#
# ==> Correct ans:   C: shortness of breath
# ==> Predicted ans: B: herpes
# None
# 203 - question: If I have a modern light source in my living room, what is it likely to be?
#
# options:
# A: sky
# B: house
# C: lamp
# D: match
# E: candle
#
# ==> Correct ans:   C: lamp
# ==> Predicted ans: E: candle
# None
# 204 - question: The person saw the mess his children made, what was his following reaction?
#
# options:
# A: smell smoke
# B: cross street
# C: cry
# D: bank savings
# E: look angry
#
# ==> Correct ans:   E: look angry
# ==> Predicted ans: A: smell smoke
# None
# 206 - question: Where would stones not be arranged in a path?
#
# options:
# A: quarries
# B: field
# C: park
# D: bridge
# E: made from rocks
#
# ==> Correct ans:   B: field
# ==> Predicted ans: C: park
# None
# 218 - question: When is the worst time for having food?
#
# options:
# A: digesting
# B: not hungry
# C: gas
# D: weight gain
# E: feeling of fullness
#
# ==> Correct ans:   B: not hungry
# ==> Predicted ans: C: gas
# None
# 242 - question: What makes someone a nomad?
#
# options:
# A: unpleasant things
# B: hangnail
# C: have no home
# D: have no car
# E: schizophrenia
#
# ==> Correct ans:   C: have no home
# ==> Predicted ans: D: have no car
# None
# 260 - question: The traveling business man was glad his credit card had perks, it offset the high prices for travel from a what?
#
# options:
# A: car
# B: theatre
# C: airport
# D: hotel
# E: disneyland
#
# ==> Correct ans:   C: airport
# ==> Predicted ans: D: hotel
# None
# 293 - question: During a shark filled tornado where should you not be?
#
# options:
# A: marine museum
# B: pool hall
# C: noodle house
# D: bad movie
# E: outside
#
# ==> Correct ans:   E: outside
# ==> Predicted ans: D: bad movie
# None
# 312 - question: What is the habitat of the fox?
#
# options:
# A: hen house
# B: burrow
# C: california
# D: england
# E: mountains
#
# ==> Correct ans:   E: mountains
# ==> Predicted ans: D: england
# None
# 314 - question: They children loved having a back yard, and the parents loved that it was a safe what?
#
# options:
# A: suburb
# B: neighborhood
# C: back of house
# D: roundabout
# E: property
#
# ==> Correct ans:   B: neighborhood
# ==> Predicted ans: E: property
# None
# 316 - question: Joe was thrown from his boat into the water. The water was cold because it was the middle of winter and he cried out to his crew for help. They couldn't hear him over the sound of the what?
#
# options:
# A: surface of earth
# B: teardrops
# C: snowflake
# D: typhoon
# E: motor
#
# ==> Correct ans:   D: typhoon
# ==> Predicted ans: C: snowflake
# None
# 327 - question: Where do you head to travel to a star?
#
# options:
# A: night sky
# B: galaxy
# C: outer space
# D: hollywood
# E: eat cake
#
# ==> Correct ans:   C: outer space
# ==> Predicted ans: D: hollywood
# None
# 328 - question: The player lifted his cornet and walked in rhythm, what was the player a member of?
#
# options:
# A: museum
# B: high school band
# C: marching band
# D: orchestra
# E: band
#
# ==> Correct ans:   C: marching band
# ==> Predicted ans: E: band
# None
# 342 - question: Pens, computers, text books and paper clips can all be found where?
#
# options:
# A: desktop
# B: university
# C: drawer
# D: table
# E: work
#
# ==> Correct ans:   B: university
# ==> Predicted ans: A: desktop
# None
# 343 - question: What geographic area is a lizard likely to be?
#
# options:
# A: ball stopped
# B: west texas
# C: arid regions
# D: garden
# E: warm place
#
# ==> Correct ans:   B: west texas
# ==> Predicted ans: E: warm place
# None
# 347 - question: As a result of dying, what happens to organic material?
#
# options:
# A: change of color
# B: stop breathing
# C: wake up
# D: death and decay
# E: getting cold
#
# ==> Correct ans:   D: death and decay
# ==> Predicted ans: A: change of color
# None
# 348 - question: What does everyone have in relation to other people?
#
# options:
# A: feelings
# B: food
# C: unique personality
# D: different standards
# E: values
#
# ==> Correct ans:   A: feelings
# ==> Predicted ans: C: unique personality
# None
# 355 - question: What is someone doing if he or she is sitting quietly and his or her eyes are moving?
#
# options:
# A: reading
# B: meditate
# C: fall asleep
# D: bunk
# E: think
#
# ==> Correct ans:   A: reading
# ==> Predicted ans: E: think
# None
# 362 - question: Batman bought beer. There were no bottles available. He had to settle for what?.
#
# options:
# A: shelf
# B: soccer game
# C: keg
# D: can
# E: refrigerator
#
# ==> Correct ans:   D: can
# ==> Predicted ans: C: keg
# None
# 372 - question: What is the most famous constellation out of earth?
#
# options:
# A: one moon
# B: milky way
# C: god's creation
# D: stars
# E: universe
#
# ==> Correct ans:   B: milky way
# ==> Predicted ans: D: stars
# None
# 373 - question: If a reception is held with hotel guests walking by, what is the likely venue?
#
# options:
# A: room service
# B: church basement
# C: lobby
# D: large room
# E: country club
#
# ==> Correct ans:   C: lobby
# ==> Predicted ans: E: country club
# None
# 387 - question: Her voice lent her to the alto section, what group did she join?
#
# options:
# A: symphony
# B: concerto
# C: choir
# D: theater troupe
# E: marching band
#
# ==> Correct ans:   C: choir
# ==> Predicted ans: B: concerto
# None
# 405 - question: Joe found spiders while checking something outside. What might that be?
#
# options:
# A: cupboard
# B: closet
# C: storage bag
# D: mail box
# E: garage
#
# ==> Correct ans:   D: mail box
# ==> Predicted ans: A: cupboard
# None
# 411 - question: How might releasing energy that has built up feel?
#
# options:
# A: damage
# B: wonderful
# C: exhaustion
# D: orgasm
# E: lazy
#
# ==> Correct ans:   B: wonderful
# ==> Predicted ans: C: exhaustion
# None
# 412 - question: What would you do if you have curiosity but are blind and paralyzed?
#
# options:
# A: hear news
# B: analyse
# C: go somewhere
# D: examine thing
# E: see favorite show
#
# ==> Correct ans:   B: analyse
# ==> Predicted ans: C: go somewhere
# None
# 414 - question: A great teacher can be what when you are attending school?
#
# options:
# A: detention
# B: graduate
# C: follower
# D: inspiration
# E: boredom
#
# ==> Correct ans:   D: inspiration
# ==> Predicted ans: B: graduate
# None
# 423 - question: The man didn't do great in college, all his best memories were late night with his brothers at the what?
#
# options:
# A: big city
# B: fraternity house
# C: school
# D: building
# E: big town
#
# ==> Correct ans:   B: fraternity house
# ==> Predicted ans: C: school
# None
# 433 - question: It's dangerous to let pet birds free so it's better to keep them what?
#
# options:
# A: slavery
# B: caught
# C: caged in
# D: topfree
# E: prisoner
#
# ==> Correct ans:   C: caged in
# ==> Predicted ans: D: topfree
# None
# 473 - question: What does a child learn to do before school?
#
# options:
# A: count to ten
# B: state name
# C: dress herself
# D: clean room
# E: socialize
#
# ==> Correct ans:   C: dress herself
# ==> Predicted ans: A: count to ten
# None
# 495 - question: What has someone who had finished their undergraduate done?
#
# options:
# A: graduated
# B: masters
# C: postgraduate
# D: phd
# E: professor
#
# ==> Correct ans:   A: graduated
# ==> Predicted ans: D: phd
# None
# 503 - question: where is seaweed from?
#
# options:
# A: beach
# B: sea
# C: ocean
# D: water
# E: sea plant
#
# ==> Correct ans:   C: ocean
# ==> Predicted ans: D: water
# None
# 522 - question: Where could there be a battle that involves words?
#
# options:
# A: court room
# B: war
# C: video game
# D: iraq
# E: church
#
# ==> Correct ans:   A: court room
# ==> Predicted ans: B: war
# None
# 523 - question: John didn't mind getting in line. It was what game after that he hated. The time, the sore feet. He did not like doing what?
#
# options:
# A: have to wait for
# B: standing in line
# C: eat cake
# D: less confusion
# E: being ordered
#
# ==> Correct ans:   B: standing in line
# ==> Predicted ans: A: have to wait for
# None
# 526 - question: The end of the barrel of what primitive firearm is bell shaped?
#
# options:
# A: barbell
# B: funnel
# C: blunderbuss
# D: wind instrument
# E: kettlebell
#
# ==> Correct ans:   C: blunderbuss
# ==> Predicted ans: E: kettlebell
# None
# 534 - question: Most people make stupid assumptions that are based on their prejudices. What might they do instead to achieve better outcomes?
#
# options:
# A: set table
# B: think
# C: read books
# D: play games
# E: lie
#
# ==> Correct ans:   B: think
# ==> Predicted ans: E: lie
# None
# 556 - question: The electrode wouldn't spark, it turned out that the what hadn't been connected?
#
# options:
# A: battery
# B: electronic equipment
# C: electrolytic cell
# D: charge
# E: tube
#
# ==> Correct ans:   A: battery
# ==> Predicted ans: E: tube
# None
# 558 - question: What must a student in engineering do?
#
# options:
# A: answer question
# B: learn language
# C: do mathematics
# D: be able to count
# E: begin to study
#
# ==> Correct ans:   C: do mathematics
# ==> Predicted ans: E: begin to study
# None
# 565 - question: I want to use string to keep something from moving, how should I do it?
#
# options:
# A: tie around
# B: wind around
# C: weave
# D: stringbed
# E: ball up
#
# ==> Correct ans:   A: tie around
# ==> Predicted ans: B: wind around
# None
# 575 - question: Christine couldn't be having a baby at her age, she thought to herself. What was Christine?
#
# options:
# A: old person
# B: begin to talk
# C: adult
# D: old man
# E: girl
#
# ==> Correct ans:   A: old person
# ==> Predicted ans: E: girl
# None
# 582 - question: What will happen if you inject water into yourself?
#
# options:
# A: dilute
# B: thin blood
# C: take several forms
# D: wet clothes
# E: move mountains
#
# ==> Correct ans:   B: thin blood
# ==> Predicted ans: D: wet clothes
# None
# 593 - question: If the president wanted to ban snakes, where would he issue such a decree?
#
# options:
# A: street
# B: tropical forest
# C: garden of eden
# D: new mexico
# E: white house
#
# ==> Correct ans:   E: white house
# ==> Predicted ans: D: new mexico
# None
# 687 - question: In basic training they build you up only to do what, all in hopes of building you up even stronger the next time?
#
# options:
# A: destroying
# B: tear down
# C: raze
# D: mutilate
# E: demolition
#
# ==> Correct ans:   B: tear down
# ==> Predicted ans: A: destroying
# None
# 693 - question: James tore the antenna off of his boat due to bad reception as he was crossing the channel from France. Where was he going?
#
# options:
# A: river
# B: television
# C: india
# D: england
# E: europe
#
# ==> Correct ans:   D: england
# ==> Predicted ans: E: europe
# None
# 702 - question: He was beginning to worry they wouldn't get on the ride before closing, they had been standing in queue for a long what?
#
# options:
# A: frustration
# B: waiting
# C: hair
# D: time
# E: patience
#
# ==> Correct ans:   D: time
# ==> Predicted ans: B: waiting
# None
# 720 - question: What is the best way to begin going into trance?
#
# options:
# A: religious experience
# B: closed eyes
# C: loss of control
# D: sleep
# E: hallucination
#
# ==> Correct ans:   B: closed eyes
# ==> Predicted ans: E: hallucination
# None
# 723 - question: In the building where James worked there was a small mezzanine in the auditorium to make more space for seats. Where might James work?
#
# options:
# A: theater
# B: floors
# C: concert hall
# D: education
# E: school
#
# ==> Correct ans:   A: theater
# ==> Predicted ans: E: school
# None
# 729 - question: If a lizard is fed by people every day, what has happened to it?
#
# options:
# A: documentary
# B: costa rica
# C: garden
# D: encouragement
# E: captivity
#
# ==> Correct ans:   E: captivity
# ==> Predicted ans: C: garden
# None
# 740 - question: Ficus can be planted in a yard to make summer more bearable, what sort of areas do they create?
#
# options:
# A: shady places
# B: screened porch
# C: pots
# D: ceramics
# E: clay pot
#
# ==> Correct ans:   A: shady places
# ==> Predicted ans: B: screened porch
# None
# 741 - question: Children's behavior is a direct reflection of their what?
#
# options:
# A: parents
# B: old people
# C: play ball
# D: many adults
# E: grown ups
#
# ==> Correct ans:   A: parents
# ==> Predicted ans: E: grown ups
# None
# 753 - question: What will likely happen after stabbing to death a person?
#
# options:
# A: gruesome
# B: being arrested
# C: pool of blood
# D: mess
# E: grisly
#
# ==> Correct ans:   B: being arrested
# ==> Predicted ans: A: gruesome
# None
# 766 - question: Why is religion so hard to understand?
#
# options:
# A: both positive and negative
# B: unknowable
# C: important to people
# D: ocean
# E: confusing
#
# ==> Correct ans:   E: confusing
# ==> Predicted ans: B: unknowable
# None
# 772 - question: What will you put on a pen to prevent it from drying out?
#
# options:
# A: write sentences on paper
# B: ink in
# C: ink cartridges
# D: caps
# E: cling film
#
# ==> Correct ans:   D: caps
# ==> Predicted ans: E: cling film
# None
# 780 - question: What type of store would have lots of sports equipment?
#
# options:
# A: mall
# B: office supply store
# C: school
# D: sporting goods store
# E: sporting event
#
# ==> Correct ans:   D: sporting goods store
# ==> Predicted ans: C: school
# None
# 788 - question: James couldn't get comfortable. There was too much dirt. He needed to clean out what?
#
# options:
# A: ground
# B: subway
# C: bank
# D: bed
# E: street
#
# ==> Correct ans:   D: bed
# ==> Predicted ans: E: street
# None
# 810 - question: He used an umbrella while tanning, where was he likely?
#
# options:
# A: waves
# B: seattle
# C: suitcase
# D: beach
# E: jacket closet
#
# ==> Correct ans:   D: beach
# ==> Predicted ans: B: seattle
# None
# 820 - question: Seeing idea become reality was a dream of hers for a long time, but as the time came to get on stage she had more what?
#
# options:
# A: build
# B: anxiety
# C: celebrate
# D: very nice
# E: ocean
#
# ==> Correct ans:   B: anxiety
# ==> Predicted ans: C: celebrate
# None
# 822 - question: Where off the eastern U.S. would you find an anemone?
#
# options:
# A: flower bed
# B: tide pool
# C: florida keys
# D: coral sea
# E: aquarium
#
# ==> Correct ans:   C: florida keys
# ==> Predicted ans: D: coral sea
# None
# 829 - question: The performer was ready to put on a show and stepped onto the launch platform, what was his job?
#
# options:
# A: cape canaveral florida
# B: nasa
# C: battleship
# D: ocean
# E: trapeze
#
# ==> Correct ans:   E: trapeze
# ==> Predicted ans: B: nasa
# None
# 834 - question: The child didn't know the problems his mother was going through, all he had was what for her?
#
# options:
# A: care
# B: balloon
# C: loved
# D: become adult
# E: learn
#
# ==> Correct ans:   C: loved
# ==> Predicted ans: A: care
# None
# 841 - question: Metal is taken from what which is pulled from the ground?
#
# options:
# A: dirt
# B: instruments
# C: ore
# D: car
# E: junkyard
#
# ==> Correct ans:   C: ore
# ==> Predicted ans: A: dirt
# None
# 847 - question: What would be happening if you are pretending to be a police officer?
#
# options:
# A: fighting
# B: misunderstanding
# C: deception
# D: play
# E: distrust
#
# ==> Correct ans:   C: deception
# ==> Predicted ans: A: fighting
# None
# 868 - question: What happens when you go somewhere and forget something at home?
#
# options:
# A: arriving
# B: arrive there
# C: turn around
# D: go back
# E: fart
#
# ==> Correct ans:   D: go back
# ==> Predicted ans: E: fart
# None
# 873 - question: Why do people who are dying receive social security payments?
#
# options:
# A: rejuvenation
# B: born again
# C: no longer exist
# D: unable to work
# E: change of color
#
# ==> Correct ans:   D: unable to work
# ==> Predicted ans: C: no longer exist
# None
# 879 - question: Where outside of a city would a squirrel live?
#
# options:
# A: roof
# B: inside home
# C: forest
# D: yard
# E: park
#
# ==> Correct ans:   C: forest
# ==> Predicted ans: E: park
# None
# 885 - question: The student explained he had a clue what neuroepithelium was and got really nervous, he then lost his balance because a what issue?
#
# options:
# A: tastebud
# B: retina
# C: inner ear
# D: nasal cavity
# E: autistic
#
# ==> Correct ans:   C: inner ear
# ==> Predicted ans: D: nasal cavity
# None
# 914 - question: Before lifting weights he liked to warm up on the squash court, he really enjoyed the facilities of the what?
#
# options:
# A: swimming pool
# B: rich person's house
# C: country club
# D: fitness center
# E: park
#
# ==> Correct ans:   D: fitness center
# ==> Predicted ans: C: country club
# None
# 943 - question: What are people likely to do when an unexpected decent outcome occurs?
#
# options:
# A: kill each other
# B: thank god
# C: experience pain
# D: hatred
# E: talk to each other
#
# ==> Correct ans:   B: thank god
# ==> Predicted ans: C: experience pain
# None
# 952 - question: What may you have after awaking after a night of heavy drinking?
#
# options:
# A: get up
# B: discomfort
# C: discomfort
# D: headache
# E: shock
#
# ==> Correct ans:   D: headache
# ==> Predicted ans: C: discomfort
# None
# 977 - question: If a person stutters when he experiences anxiety or excitement, he'll have difficult doing what?
#
# options:
# A: express information
# B: dance
# C: library
# D: go somewhere
# E: study
#
# ==> Correct ans:   A: express information
# ==> Predicted ans: E: study
# None
# 1006 - question: What do you feel when giving assistance to the needy?
#
# options:
# A: reward
# B: boredom
# C: pleasure
# D: happiness
# E: satisfaction
#
# ==> Correct ans:   E: satisfaction
# ==> Predicted ans: C: pleasure
# None
# 1025 - question: Why do people stop caring about their problems?
#
# options:
# A: no problems
# B: better themselves
# C: face problems
# D: learn from each other
# E: become disillusioned
#
# ==> Correct ans:   E: become disillusioned
# ==> Predicted ans: A: no problems
# None
# 1035 - question: Where is hard to read note likely to be?
#
# options:
# A: fridge
# B: sheet music
# C: desk
# D: bed
# E: medical chart
#
# ==> Correct ans:   E: medical chart
# ==> Predicted ans: C: desk
# None
# 1049 - question: Where do you buy condoms?
#
# options:
# A: supermarket
# B: sock drawer
# C: cd store
# D: medicine chest
# E: bedroom
#
# ==> Correct ans:   A: supermarket
# ==> Predicted ans: C: cd store
# None
# 1057 - question: James was someone who was caught in his own delusions. To him, the truth didn't do what what?
#
# options:
# A: work to advantage
# B: matter to
# C: help
# D: free mind
# E: further knowledge
#
# ==> Correct ans:   B: matter to
# ==> Predicted ans: D: free mind
# None
# 1106 - question: Where is a lake likely to be glacial?
#
# options:
# A: michigan
# B: new york
# C: new york
# D: mountains
# E: countryside
#
# ==> Correct ans:   D: mountains
# ==> Predicted ans: A: michigan
# None
# 1113 - question: The place where my linen closet is really needs repainting a light color as it only has one overhead light.
#
# options:
# A: house
# B: home
# C: pool house
# D: hallway
# E: bedroom
#
# ==> Correct ans:   D: hallway
# ==> Predicted ans: E: bedroom
# None
# 1138 - question: Sarah gave her brother a guy to her home. While she was gone, he used it to do what?
#
# options:
# A: front door
# B: turn lock
# C: solution to problem
# D: install
# E: open doors
#
# ==> Correct ans:   E: open doors
# ==> Predicted ans: B: turn lock
# None
# 1155 - question: The potato might be the official vegetable of what?
#
# options:
# A: vegans
# B: kitchen cupboard
# C: restaurants
# D: chicken
# E: maryland
#
# ==> Correct ans:   E: maryland
# ==> Predicted ans: C: restaurants
# None
# 1178 - question: When cooking sheep meat a lot of people might want to be well?
#
# options:
# A: ram
# B: lamb
# C: done
# D: ram
# E: wolf
#
# ==> Correct ans:   C: done
# ==> Predicted ans: E: wolf
# None
# 1180 - question: Farm land makes use of what?
#
# options:
# A: countryside
# B: michigan
# C: north dakota
# D: farming areas
# E: illinois
#
# ==> Correct ans:   D: farming areas
# ==> Predicted ans: A: countryside
# None
# 1182 - question: Computers have allowed everybody to answer questions they have quickly, but still we seem to be getting duller despite access to this what?
#
# options:
# A: economic boom
# B: advance knowledge
# C: produce sound
# D: teach
# E: follow instructions
#
# ==> Correct ans:   B: advance knowledge
# ==> Predicted ans: C: produce sound
# None
# 1186 - question: What would you need if you want to smoke?
#
# options:
# A: you're stupid
# B: kill yourself
# C: roll joint
# D: cigarette
# E: lighter fluid.
#
# ==> Correct ans:   D: cigarette
# ==> Predicted ans: E: lighter fluid
# None
# 1200 - question: Why would you not trust your friends after chatting with friends?
#
# options:
# A: fever
# B: smoke
# C: laughing
# D: coughing
# E: lie
#
# ==> Correct ans:   E: lie
# ==> Predicted ans: B: smoke
# None
# 1207 - question: David watched some nesting birds using his binoculars while on vacation. Where might David be?.
#
# options:
# A: sky
# B: vaccation
# C: forest
# D: countryside
# E: roof
#
# ==> Correct ans:   C: forest
# ==> Predicted ans: D: countryside
# None

# %%
counter = 0

while counter <= 10:
    for idx in t5_cos_ans.incorrect_idxs:
        if idx not in t5_so_ans.incorrect_idxs:
            print(t5_cos_ans.get_example(idx))
            counter += 1
# Out:
# 2 - question: Where would you find magazines along side many other printed works?
#
# options:
# A: doctor
# B: bookstore
# C: market
# D: train station
# E: mortuary
#
# ==> Correct ans:   B: bookstore
# ==> Predicted ans: C: market
# None
# 25 - question: When wildlife reproduce we often refer to what comes out as what?
#
# options:
# A: raise children
# B: have children
# C: photo copy
# D: offspring
# E: accidently got pregnant somehow
#
# ==> Correct ans:   D: offspring
# ==> Predicted ans: C: photo copy
# None
# 31 - question: James wanted to find an old underground map from the 50s. Where might he look for one?
#
# options:
# A: library
# B: subway station
# C: county engineer's office
# D: super market
# E: home
#
# ==> Correct ans:   A: library
# ==> Predicted ans: B: subway station
# None
# 32 - question: Sean was in a rush to get home, but the light turned yellow and he was forced to do what?
#
# options:
# A: take time
# B: dawdle
# C: go slowly
# D: ocean
# E: slow down
#
# ==> Correct ans:   E: slow down
# ==> Predicted ans: A: take time
# None
# 43 - question: Where can you put a picture frame when it's not hung vertically?
#
# options:
# A: art show
# B: wall
# C: newspaper
# D: car
# E: table
#
# ==> Correct ans:   E: table
# ==> Predicted ans: B: wall
# None
# 50 - question: Where can a human find clothes that aren't pants?
#
# options:
# A: pants shop
# B: on planet earth
# C: dress shop
# D: school
# E: train wreck
#
# ==> Correct ans:   C: dress shop
# ==> Predicted ans: D: school
# None
# 72 - question: The kids didn't clean up after they had done what?
#
# options:
# A: learn things
# B: play games
# C: disneyland
# D: play with toys
# E: talking
#
# ==> Correct ans:   D: play with toys
# ==> Predicted ans: A: learn things
# None
# 85 - question: The man had a fear of illness, so he never visited friends who were a what?
#
# options:
# A: sick person
# B: hospital
# C: elderly person
# D: graveyard
# E: doctor's office
#
# ==> Correct ans:   A: sick person
# ==> Predicted ans: C: elderly person
# None
# 96 - question: Billy set aside a block of time for having fun after work. Why might he do this?
#
# options:
# A: happiness
# B: stress relief
# C: pleasure
# D: ocean
# E: may laugh
#
# ==> Correct ans:   B: stress relief
# ==> Predicted ans: C: pleasure
# None
# 114 - question: A man wants air conditioning while we watches the game on Saturday, where will it likely be installed?
#
# options:
# A: car
# B: house
# C: offices
# D: park
# E: movie theatre
#
# ==> Correct ans:   B: house
# ==> Predicted ans: E: movie theatre
# None
# 150 - question: Jenny enjoyed helping people. It brought her a great deal of what?
#
# options:
# A: satisfaction
# B: complications
# C: train
# D: feel good about yourself
# E: enjoyment
#
# ==> Correct ans:   A: satisfaction
# ==> Predicted ans: E: enjoyment
# None
# 168 - question: Where are people likely to become impatient?
#
# options:
# A: end of line
# B: buildings
# C: apartment
# D: neighbor's house
# E: address
#
# ==> Correct ans:   A: end of line
# ==> Predicted ans: B: buildings
# None
# 171 - question: When you get together with friends to watch film, you might do plenty of this?
#
# options:
# A: see what happens
# B: enjoy stories
# C: pass time
# D: have fun
# E: interesting
#
# ==> Correct ans:   D: have fun
# ==> Predicted ans: B: enjoy stories
# None
# 201 - question: What part of a table would you put a ruler in?
#
# options:
# A: drawer
# B: desk
# C: the backside
# D: office
# E: measure distance
#
# ==> Correct ans:   A: drawer
# ==> Predicted ans: B: desk
# None
# 235 - question: The lady would eat and eat, and because of mental issues would then make herself what?
#
# options:
# A: wash dishes
# B: throwing up
# C: drinking
# D: throw up
# E: turn inside out
#
# ==> Correct ans:   D: throw up
# ==> Predicted ans: C: drinking
# None
# 237 - question: What do you go to see for live entertainment?
#
# options:
# A: movie
# B: show
# C: concert venue
# D: casino
# E: theatre
#
# ==> Correct ans:   B: show
# ==> Predicted ans: C: concert venue
# None
# 245 - question: The fact that Joe was able to memorize the list in spite of his apparent state proved that part of his brain was what?
#
# options:
# A: awake
# B: repeat
# C: sleeping
# D: concentrate
# E: read aloud
#
# ==> Correct ans:   A: awake
# ==> Predicted ans: D: concentrate
# None
# 258 - question: What might a couple have a lot of when they are deciding on stopping being married to each other?
#
# options:
# A: pleasure
# B: detachment
# C: exercise
# D: bankruptcy
# E: fights
#
# ==> Correct ans:   E: fights
# ==> Predicted ans: B: detachment
# None
# 351 - question: What do you do when you're in a new place and want to see new things?
#
# options:
# A: interesting
# B: look around
# C: take pictures
# D: change of surroundings
# E: new experience
#
# ==> Correct ans:   B: look around
# ==> Predicted ans: C: take pictures
# None
# 389 - question: Animals who have hair and don't lay eggs are what?
#
# options:
# A: reproduce asexually
# B: males
# C: mammals
# D: attack
# E: ocean
#
# ==> Correct ans:   C: mammals
# ==> Predicted ans: B: males
# None
# 395 - question: How is riding a bike getting it to move?
#
# options:
# A: practice
# B: sense of balance
# C: driving
# D: good balance
# E: pedalling
#
# ==> Correct ans:   E: pedalling
# ==> Predicted ans: A: practice
# None
# 402 - question: I want my wine stored in darkness, where should it go?
#
# options:
# A: movies
# B: bed
# C: moon
# D: vault
# E: cellar
#
# ==> Correct ans:   E: cellar
# ==> Predicted ans: D: vault
# None
# 403 - question: If I want to open a steakhouse, what should I get first?
#
# options:
# A: michigan
# B: florida
# C: wine
# D: texas
# E: building
#
# ==> Correct ans:   E: building
# ==> Predicted ans: A: michigan
# None
# 408 - question: Most items in retail stores are what even when they are on sale?
#
# options:
# A: overpriced
# B: purchase
# C: expensive
# D: park
# E: buying
#
# ==> Correct ans:   A: overpriced
# ==> Predicted ans: C: expensive
# None
# 432 - question: When we are running what are we doing?
#
# options:
# A: stretches
# B: running from police
# C: learn to walk
# D: go quickly
# E: get out of bed
#
# ==> Correct ans:   D: go quickly
# ==> Predicted ans: B: running from police
# None
# 441 - question: The criminal insisted he must do the crime to the bank teller, but she tried to convince him there were other ways in life and this was what?
#
# options:
# A: willing
# B: optional
# C: should not
# D: have to
# E: unnecessary
#
# ==> Correct ans:   E: unnecessary
# ==> Predicted ans: C: should not
# None
# 448 - question: Where would a cat snuggle up with their human?
#
# options:
# A: floor
# B: humane society
# C: bed
# D: comfortable chair
# E: window sill
#
# ==> Correct ans:   D: comfortable chair
# ==> Predicted ans: C: bed
# None
# 454 - question: If somebody is working at a reception desk, they are located at the front entrance of the what?
#
# options:
# A: motel
# B: hostel
# C: building
# D: lobby
# E: office park
#
# ==> Correct ans:   C: building
# ==> Predicted ans: D: lobby
# None
# 461 - question: What is it called when two people in love have children?
#
# options:
# A: take oath
# B: procreate
# C: matrimony
# D: please parents
# E: live life
#
# ==> Correct ans:   B: procreate
# ==> Predicted ans: C: matrimony
# None
# 468 - question: What would you put coins into to make it work?
#
# options:
# A: stove
# B: water fountain
# C: desk
# D: purse
# E: jar
#
# ==> Correct ans:   B: water fountain
# ==> Predicted ans: E: jar
# None
# 470 - question: Where can you go to use a piano in your neighborhood if you don't have one?
#
# options:
# A: music school
# B: music store
# C: neighbor's house
# D: lunch
# E: drawing room
#
# ==> Correct ans:   C: neighbor's house
# ==> Predicted ans: B: music store
# None
# 480 - question: Name a location where you would not want to find mice.
#
# options:
# A: loft
# B: attic
# C: bell cat
# D: countryside
# E: laboratory
#
# ==> Correct ans:   B: attic
# ==> Predicted ans: D: countryside
# None
# 489 - question: Where would you keep a rug near your front door?
#
# options:
# A: persia
# B: desk
# C: table
# D: living room
# E: hall
#
# ==> Correct ans:   D: living room
# ==> Predicted ans: E: hall
# None
# 510 - question: Everybody seemed to be crying at the holy site, the tour guide explained that this was what?
#
# options:
# A: profane
# B: halibut
# C: damaged
# D: common
# E: halibut
#
# ==> Correct ans:   D: common
# ==> Predicted ans: A: profane
# None
# 525 - question: The old man needed to have rest multiple times a day, he would do what on the couch and catnap?
#
# options:
# A: lay in bed
# B: lay in bed
# C: go to bed
# D: relax
# E: lie down
#
# ==> Correct ans:   E: lie down
# ==> Predicted ans: A: lay in bed
# None
# 532 - question: A story about World War II would be set when?
#
# options:
# A: book or library
# B: book or magazine
# C: newspaper
# D: past
# E: future
#
# ==> Correct ans:   D: past
# ==> Predicted ans: E: future
# None
# 553 - question: If it's not used for hair a round brush is an example of what?
#
# options:
# A: hair brush
# B: ladies bathroom
# C: art supplies
# D: shower
# E: hair salon
#
# ==> Correct ans:   C: art supplies
# ==> Predicted ans: A: hair brush
# None
# 570 - question: What do people do when they think too quickly?
#
# options:
# A: jump to conclusions
# B: hurry home
# C: build trust
# D: pay bills
# E: sing
#
# ==> Correct ans:   A: jump to conclusions
# ==> Predicted ans: B: hurry home
# None
# 613 - question: Why would you take a bus to work?
#
# options:
# A: commute
# B: flying
# C: get somewhere
# D: travel
# E: go home
#
# ==> Correct ans:   A: commute
# ==> Predicted ans: C: get somewhere
# None
# 627 - question: The town house went right to the curb, a slot effectively made a mailbox of the what?
#
# options:
# A: apartment building
# B: front door
# C: back door
# D: street corner
# E: porch
#
# ==> Correct ans:   B: front door
# ==> Predicted ans: D: street corner
# None
# 628 - question: The architect thought that a mezzanine would look good, but the planning committee rejected it. They told the architect that they felt it was a potential hazard given the ages of the people who would be using it. What might they be designing?
#
# options:
# A: actors
# B: theater
# C: concert hall
# D: floors
# E: school
#
# ==> Correct ans:   E: school
# ==> Predicted ans: C: concert hall
# None
# 650 - question: He was trying to procreate with many individuals, this led to a what?
#
# options:
# A: moaning
# B: die
# C: kiss
# D: std
# E: sanity
#
# ==> Correct ans:   D: std
# ==> Predicted ans: B: die
# None
# 666 - question: Where is there a telephone book in almost every room?
#
# options:
# A: at hotel
# B: house
# C: library
# D: bedsit
# E: closet
#
# ==> Correct ans:   A: at hotel
# ==> Predicted ans: C: library
# None
# 689 - question: John and Judy were parents. They had two wonderful kids who weren't always well behaved. They were light tough, though. They felt it was a parent's job to do what?
#
# options:
# A: control children
# B: guide children
# C: speak freely
# D: cry
# E: understand children
#
# ==> Correct ans:   B: guide children
# ==> Predicted ans: E: understand children
# None
# 691 - question: If somebody buys something and gives it to me as a free gift, what is the cost status of the gift?
#
# options:
# A: deadly
# B: imprisoned
# C: paid for
# D: expensive
# E: in prison
#
# ==> Correct ans:   C: paid for
# ==> Predicted ans: D: expensive
# None
# 709 - question: How does a person begin reproducing?
#
# options:
# A: genetic mutation
# B: have sex
# C: kiss
# D: flirting
# E: going on a date
#
# ==> Correct ans:   B: have sex
# ==> Predicted ans: A: genetic mutation
# None
# 739 - question: If I wanted to eat something that is made from plants and needs to be washed, what would it be?
#
# options:
# A: roots
# B: millions of cells
# C: see work
# D: leaves to gather light
# E: flowers on
#
# ==> Correct ans:   A: roots
# ==> Predicted ans: E: flowers on
# None
# 750 - question: Sean was leaving work and took the roadway that led to his what?
#
# options:
# A: neighborhood
# B: city
# C: fate
# D: countryside
# E: maps
#
# ==> Correct ans:   A: neighborhood
# ==> Predicted ans: B: city
# None
# 768 - question: What would a person need to do if his or her captain dies at sea?
#
# options:
# A: cross street
# B: have a party
# C: experience life
# D: cross road
# E: man crew
#
# ==> Correct ans:   E: man crew
# ==> Predicted ans: C: experience life
# None
# 770 - question: I house outside the center of a community is said to be where?
#
# options:
# A: city
# B: subdivision
# C: newspaper
# D: residential area
# E: street
#
# ==> Correct ans:   B: subdivision
# ==> Predicted ans: D: residential area
# None
# 777 - question: What would you be building if you designed a place for an annoying critter to stay?
#
# options:
# A: spread disease
# B: swamp
# C: fly away
# D: cat condo
# E: bug campers
#
# ==> Correct ans:   E: bug campers
# ==> Predicted ans: D: cat condo
# None
# 778 - question: The man working in the attic swatted away a bee, but soon the single bee was an entire what?
#
# options:
# A: swarm
# B: pack
# C: countryside
# D: soft drink
# E: field of flowers
#
# ==> Correct ans:   A: swarm
# ==> Predicted ans: B: pack
# None
# 786 - question: Which group of states is Louisiana part of?
#
# options:
# A: deep south
# B: 98 of world's crayfish
# C: united states
# D: gulf states
# E: bible belt
#
# ==> Correct ans:   D: gulf states
# ==> Predicted ans: C: united states
# None
# 803 - question: When getting in shape, this is something that does wonders?
#
# options:
# A: eat more
# B: starve
# C: give up
# D: period of recovery
# E: jogging
#
# ==> Correct ans:   E: jogging
# ==> Predicted ans: D: period of recovery
# None
# 806 - question: What is a person likely to experience after they stop being married to a mean person?
#
# options:
# A: isolation
# B: grief
# C: happiness
# D: relief
# E: angry
#
# ==> Correct ans:   C: happiness
# ==> Predicted ans: A: isolation
# None
# 809 - question: The dog curled up for a nap, it was tuckered out because it had just been what?
#
# options:
# A: walked
# B: petted
# C: affection
# D: go outside
# E: scratch
#
# ==> Correct ans:   A: walked
# ==> Predicted ans: E: scratch
# None
# 821 - question: A creek could be located in the opposite for the city which is called what?
#
# options:
# A: meadow
# B: stick
# C: valley
# D: forest
# E: countryside
#
# ==> Correct ans:   E: countryside
# ==> Predicted ans: C: valley
# None
# 840 - question: John needed a straight wire. Unfortunately, this one had endured some abuse and had become what?
#
# options:
# A: bent
# B: bent
# C: crooked
# D: straightforth
# E: curved
#
# ==> Correct ans:   A: bent
# ==> Predicted ans: C: crooked
# None
# 861 - question: She asked her little boy why, he replied that he didn't know and it was just what?
#
# options:
# A: case
# B: reason
# C: how
# D: because
# E: answer
#
# ==> Correct ans:   D: because
# ==> Predicted ans: B: reason
# None
# 865 - question: The department to where vendors deliver goods for sale is called what?
#
# options:
# A: delivered
# B: take away
# C: receiving
# D: pick up
# E: keep
#
# ==> Correct ans:   C: receiving
# ==> Predicted ans: D: pick up
# None
# 881 - question: At the end of the day as he began to eat he paused and thanked her, it wasn't often she would what?
#
# options:
# A: cook dinner
# B: did chores
# C: make food
# D: stretch out
# E: get food
#
# ==> Correct ans:   A: cook dinner
# ==> Predicted ans: E: get food
# None
# 896 - question: What do young boys do on the ice in the winter?
#
# options:
# A: ski
# B: play hockey
# C: summer
# D: knit
# E: warm
#
# ==> Correct ans:   B: play hockey
# ==> Predicted ans: A: ski
# None
# 898 - question: I listened to lecture intensely, what is my goal?
#
# options:
# A: gain confidence
# B: concentrate
# C: get attention
# D: pay attention
# E: stop talking
#
# ==> Correct ans:   B: concentrate
# ==> Predicted ans: C: get attention
# None
# 919 - question: James need to use a toilet but there were no public ones in sight. Eventually he broke down and did something very expensive so that he could get a toilet. Where might he have gone?
#
# options:
# A: motel room
# B: apartment
# C: bathroom
# D: games
# E: house
#
# ==> Correct ans:   A: motel room
# ==> Predicted ans: E: house
# None
# 921 - question: What is a person looking for when completing puzzles or riddles?
#
# options:
# A: avoid pain
# B: compliments
# C: intellectual challenge
# D: passing grade
# E: attention
#
# ==> Correct ans:   C: intellectual challenge
# ==> Predicted ans: E: attention
# None
# 967 - question: If student got a list of supplies from class like paper and pencils, their parent would have to go where?
#
# options:
# A: classroom
# B: parking garage
# C: store
# D: backpack
# E: cabinet
#
# ==> Correct ans:   C: store
# ==> Predicted ans: A: classroom
# None
# 968 - question: Why do young people swallow semen?
#
# options:
# A: you're into
# B: prostitute
# C: you're curious
# D: curiosity
# E: heterosexual woman in love
#
# ==> Correct ans:   C: you're curious
# ==> Predicted ans: D: curiosity
# None
# 974 - question: After the weight cut he was worried about his energy levels, but this was part of participating in a what?
#
# options:
# A: work
# B: wrestle
# C: play sports
# D: matter
# E: sleep
#
# ==> Correct ans:   B: wrestle
# ==> Predicted ans: C: play sports
# None
# 1003 - question: Where would using a boat not require navigation skills?
#
# options:
# A: water
# B: ocean
# C: garage
# D: harbor
# E: river
#
# ==> Correct ans:   E: river
# ==> Predicted ans: D: harbor
# None
# 1027 - question: They were never going to be big actors, but they all had passion for the local what?
#
# options:
# A: theater
# B: opera
# C: show
# D: television
# E: blockbuster feature
#
# ==> Correct ans:   A: theater
# ==> Predicted ans: C: show
# None
# 1037 - question: If there is gum on your shoe where did it likely come from?
#
# options:
# A: shelf
# B: movies
# C: sidewalk
# D: water fountain
# E: table
#
# ==> Correct ans:   C: sidewalk
# ==> Predicted ans: D: water fountain
# None
# 1040 - question: Steve thought that it was possible, but he agreed that it was what?
#
# options:
# A: no go
# B: unable
# C: unlikely
# D: impossibility
# E: cant do
#
# ==> Correct ans:   C: unlikely
# ==> Predicted ans: D: impossibility
# None
# 1068 - question: The flower grew tall to compete for sunlight, what did its neighbor do?
#
# options:
# A: blossom
# B: park
# C: open
# D: cast shadow
# E: vase
#
# ==> Correct ans:   D: cast shadow
# ==> Predicted ans: C: open
# None
# 1079 - question: The newlyweds began copulating their marriage, they wanted many what?
#
# options:
# A: babies
# B: odors
# C: sadness
# D: rapport
# E: ejaculation
#
# ==> Correct ans:   A: babies
# ==> Predicted ans: D: rapport
# None
# 1086 - question: Dance can be elegant and specific, or you can just have fun and what?
#
# options:
# A: falling down
# B: trip
# C: fall down
# D: move around
# E: celebrate
#
# ==> Correct ans:   D: move around
# ==> Predicted ans: E: celebrate
# None
# 1093 - question: What is likely to have a better school cafeteria?
#
# options:
# A: high school
# B: canteen
# C: polytechnic
# D: large room
# E: all kinds of schools
#
# ==> Correct ans:   C: polytechnic
# ==> Predicted ans: A: high school
# None
# 1098 - question: How does going jogging generally affect one's self esteem?
#
# options:
# A: feel better
# B: feel pride
# C: sweating
# D: ocean
# E: arthritis
#
# ==> Correct ans:   A: feel better
# ==> Predicted ans: B: feel pride
# None
# 1110 - question: Where areas are there likely to be many nightclubs?
#
# options:
# A: manhattan
# B: drink and dance
# C: alcohol
# D: major city
# E: downtown area
#
# ==> Correct ans:   D: major city
# ==> Predicted ans: E: downtown area
# None
# 1120 - question: Why does someone want to examine thing closely?
#
# options:
# A: buy
# B: learn about
# C: buy
# D: complex
# E: interesting
#
# ==> Correct ans:   B: learn about
# ==> Predicted ans: E: interesting
# None
# 1122 - question: Where would your hear a bass clarinet along side other wood wind instruments?
#
# options:
# A: opera house
# B: school band
# C: music store
# D: orchestra
# E: bathroom stall
#
# ==> Correct ans:   D: orchestra
# ==> Predicted ans: B: school band
# None
# 1132 - question: What do you do when you're going to market?
#
# options:
# A: buy food
# B: see other people
# C: buying vegetables
# D: buy a fat pig
# E: traveling
#
# ==> Correct ans:   A: buy food
# ==> Predicted ans: E: traveling
# None
# 1160 - question: I am cold, what should I do to stay warm?
#
# options:
# A: stay in bed
# B: light fire
# C: freezer
# D: lay on ice
# E: spit
#
# ==> Correct ans:   B: light fire
# ==> Predicted ans: A: stay in bed
# None
# 1162 - question: What do audiences clap for?
#
# options:
# A: cinema
# B: theatre
# C: movies
# D: show
# E: hockey game
#
# ==> Correct ans:   D: show
# ==> Predicted ans: E: hockey game
# None
# 1176 - question: She had an interest in the man, what did she want to do with him?
#
# options:
# A: see particular program
# B: see exhibits
# C: see people play game
# D: have conversation
# E: watch film
#
# ==> Correct ans:   D: have conversation
# ==> Predicted ans: E: watch film
# None
# 1183 - question: There was a long cottage somewhere. People thought it was haunted. It was overgrown, there was nothing near it. It's was far into the what?
#
# options:
# A: mountains
# B: countryside
# C: train
# D: painting
# E: village
#
# ==> Correct ans:   B: countryside
# ==> Predicted ans: A: mountains
# None
# 1214 - question: Tweed is a rare fabric in modern clothing, what brand should I look for when buying it?
#
# options:
# A: scotland
# B: brown
# C: fabric store
# D: clothing stores
# E: eddie bauer
#
# ==> Correct ans:   E: eddie bauer
# ==> Predicted ans: D: clothing stores
# None
